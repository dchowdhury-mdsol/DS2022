# %% [markdown]
# # Data and How To Source It

# %% [markdown]
# # What is an API?

# %% [markdown]
# API stands for Application Programming Interface

# %% [markdown]
# # How do we make HTTPS requests in Python

# %%
import requests

# %%
# Issues a get request to the API Endpoint
r = requests.get('https://api.github.com/events')

# %%
#Attribute that gets me the raw text as a string
r.text
# Out:
# '[{"id":"20962391598","type":"PushEvent","actor":{"id":25180681,"login":"renovate-bot","display_login":"renovate-bot","gravatar_id":"","url":"https://api.github.com/users/renovate-bot","avatar_url":"https://avatars.githubusercontent.com/u/25180681?"},"repo":{"id":287383519,"name":"renovate-bot/python-docs-samples-1","url":"https://api.github.com/repos/renovate-bot/python-docs-samples-1"},"payload":{"push_id":9462562735,"size":0,"distinct_size":0,"ref":"refs/heads/main","head":"fe8dd4ce6953f40afa7e6b5b797b22e7f4daf546","before":"fe8dd4ce6953f40afa7e6b5b797b22e7f4daf546","commits":[]},"public":true,"created_at":"2022-03-28T00:19:50Z"},{"id":"20962391593","type":"PushEvent","actor":{"id":6132122,"login":"matthieugouel","display_login":"matthieugouel","gravatar_id":"","url":"https://api.github.com/users/matthieugouel","avatar_url":"https://avatars.githubusercontent.com/u/6132122?"},"repo":{"id":445773604,"name":"dioptra-io/iris-uptime","url":"https://api.github.com/repos/dioptra-io/iris-uptime"},"payload":{"push_id":9462562736,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"ee5ed6bf7ea5679195cc1c30f1c057195ff959c9","before":"c10258a0df3eaff1e69332a46a7a8e77b455a2cb","commits":[{"sha":"ee5ed6bf7ea5679195cc1c30f1c057195ff959c9","author":{"email":"73812536+upptime-bot@users.noreply.github.com","name":"Upptime Bot"},"message":":bento: Update graphs [skip ci]","distinct":true,"url":"https://api.github.com/repos/dioptra-io/iris-uptime/commits/ee5ed6bf7ea5679195cc1c30f1c057195ff959c9"}]},"public":true,"created_at":"2022-03-28T00:19:50Z","org":{"id":61322981,"login":"dioptra-io","gravatar_id":"","url":"https://api.github.com/orgs/dioptra-io","avatar_url":"https://avatars.githubusercontent.com/u/61322981?"}},{"id":"20962391596","type":"DeleteEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":317294644,"name":"Walidnurudin/nuxtjs-pemula","url":"https://api.github.com/repos/Walidnurudin/nuxtjs-pemula"},"payload":{"ref":"dependabot/npm_and_yarn/prettier-2.6.0","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2022-03-28T00:19:50Z"},{"id":"20962391582","type":"PushEvent","actor":{"id":58833107,"login":"idzwdk333","display_login":"idzwdk333","gravatar_id":"","url":"https://api.github.com/users/idzwdk333","avatar_url":"https://avatars.githubusercontent.com/u/58833107?"},"repo":{"id":227725053,"name":"idzwdk333/ntdtv","url":"https://api.github.com/repos/idzwdk333/ntdtv"},"payload":{"push_id":9462562728,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"3d1e0f8f1b235cd65d5872d6cac9caa423cbb82e","before":"dd6af6d6211602395533e6c8aee5acb03bffdc9f","commits":[{"sha":"3d1e0f8f1b235cd65d5872d6cac9caa423cbb82e","author":{"email":"58833107+idzwdk333@users.noreply.github.com","name":"idzwdk333"},"message":"Update a103384929.md","distinct":true,"url":"https://api.github.com/repos/idzwdk333/ntdtv/commits/3d1e0f8f1b235cd65d5872d6cac9caa423cbb82e"}]},"public":true,"created_at":"2022-03-28T00:19:50Z"},{"id":"20962391592","type":"PushEvent","actor":{"id":90729484,"login":"jcabot01","display_login":"jcabot01","gravatar_id":"","url":"https://api.github.com/users/jcabot01","avatar_url":"https://avatars.githubusercontent.com/u/90729484?"},"repo":{"id":474791561,"name":"jcabot01/phase-3-ruby-oo-inheritance-defining-inheritance","url":"https://api.github.com/repos/jcabot01/phase-3-ruby-oo-inheritance-defining-inheritance"},"payload":{"push_id":9462562727,"size":1,"distinct_size":1,"ref":"refs/heads/fis-wip","head":"d7fa7b05d9bccfd5e49651aa7eb82a4ef576c159","before":"79acc4a5d3344dab061f03d229101a7aa205cc08","commits":[{"sha":"d7fa7b05d9bccfd5e49651aa7eb82a4ef576c159","author":{"email":"jfc0053@gmail.com","name":"JonCabot"},"message":"commit tree 7bdfac2abadd8c2abde01e28635d59d481e2aded","distinct":true,"url":"https://api.github.com/repos/jcabot0 ...

# %%
r.json()[0]
# Out:
# {'id': '20962391598',
#  'type': 'PushEvent',
#  'actor': {'id': 25180681,
#   'login': 'renovate-bot',
#   'display_login': 'renovate-bot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/renovate-bot',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/25180681?'},
#  'repo': {'id': 287383519,
#   'name': 'renovate-bot/python-docs-samples-1',
#   'url': 'https://api.github.com/repos/renovate-bot/python-docs-samples-1'},
#  'payload': {'push_id': 9462562735,
#   'size': 0,
#   'distinct_size': 0,
#   'ref': 'refs/heads/main',
#   'head': 'fe8dd4ce6953f40afa7e6b5b797b22e7f4daf546',
#   'before': 'fe8dd4ce6953f40afa7e6b5b797b22e7f4daf546',
#   'commits': []},
#  'public': True,
#  'created_at': '2022-03-28T00:19:50Z'}

# %%
# It's as simple as that. Sometimes, the encoding isn't right. Requests tries to infer
# What encoding to use, so you can change it manually with
# r.encoding = 'encoding_to_use'
# We can see that the returned object is what we are operating on.
#UTF-8

# %% [markdown]
# # Let's work through an example

# %%
r = requests.get('https://data.cityofnewyork.us/resource/f9bf-2cp4.json')

# %%
r.text
# Out:
# '[{"dbn":"01M292","school_name":"HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES","num_of_sat_test_takers":"29","sat_critical_reading_avg_score":"355","sat_math_avg_score":"404","sat_writing_avg_score":"363"}\n,{"dbn":"01M448","school_name":"UNIVERSITY NEIGHBORHOOD HIGH SCHOOL","num_of_sat_test_takers":"91","sat_critical_reading_avg_score":"383","sat_math_avg_score":"423","sat_writing_avg_score":"366"}\n,{"dbn":"01M450","school_name":"EAST SIDE COMMUNITY SCHOOL","num_of_sat_test_takers":"70","sat_critical_reading_avg_score":"377","sat_math_avg_score":"402","sat_writing_avg_score":"370"}\n,{"dbn":"01M458","school_name":"FORSYTH SATELLITE ACADEMY","num_of_sat_test_takers":"7","sat_critical_reading_avg_score":"414","sat_math_avg_score":"401","sat_writing_avg_score":"359"}\n,{"dbn":"01M509","school_name":"MARTA VALLE HIGH SCHOOL","num_of_sat_test_takers":"44","sat_critical_reading_avg_score":"390","sat_math_avg_score":"433","sat_writing_avg_score":"384"}\n,{"dbn":"01M515","school_name":"LOWER EAST SIDE PREPARATORY HIGH SCHOOL","num_of_sat_test_takers":"112","sat_critical_reading_avg_score":"332","sat_math_avg_score":"557","sat_writing_avg_score":"316"}\n,{"dbn":"01M539","school_name":"NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND MATH HIGH SCHOOL","num_of_sat_test_takers":"159","sat_critical_reading_avg_score":"522","sat_math_avg_score":"574","sat_writing_avg_score":"525"}\n,{"dbn":"01M650","school_name":"CASCADES HIGH SCHOOL","num_of_sat_test_takers":"18","sat_critical_reading_avg_score":"417","sat_math_avg_score":"418","sat_writing_avg_score":"411"}\n,{"dbn":"01M696","school_name":"BARD HIGH SCHOOL EARLY COLLEGE","num_of_sat_test_takers":"130","sat_critical_reading_avg_score":"624","sat_math_avg_score":"604","sat_writing_avg_score":"628"}\n,{"dbn":"02M047","school_name":"47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECONDARY SCHOOL","num_of_sat_test_takers":"16","sat_critical_reading_avg_score":"395","sat_math_avg_score":"400","sat_writing_avg_score":"387"}\n,{"dbn":"02M288","school_name":"FOOD AND FINANCE HIGH SCHOOL","num_of_sat_test_takers":"62","sat_critical_reading_avg_score":"409","sat_math_avg_score":"393","sat_writing_avg_score":"392"}\n,{"dbn":"02M294","school_name":"ESSEX STREET ACADEMY","num_of_sat_test_takers":"53","sat_critical_reading_avg_score":"394","sat_math_avg_score":"384","sat_writing_avg_score":"378"}\n,{"dbn":"02M296","school_name":"HIGH SCHOOL OF HOSPITALITY MANAGEMENT","num_of_sat_test_takers":"58","sat_critical_reading_avg_score":"374","sat_math_avg_score":"375","sat_writing_avg_score":"362"}\n,{"dbn":"02M298","school_name":"PACE HIGH SCHOOL","num_of_sat_test_takers":"85","sat_critical_reading_avg_score":"423","sat_math_avg_score":"438","sat_writing_avg_score":"432"}\n,{"dbn":"02M300","school_name":"URBAN ASSEMBLY SCHOOL OF DESIGN AND CONSTRUCTION, THE","num_of_sat_test_takers":"48","sat_critical_reading_avg_score":"404","sat_math_avg_score":"449","sat_writing_avg_score":"416"}\n,{"dbn":"02M303","school_name":"FACING HISTORY SCHOOL, THE","num_of_sat_test_takers":"76","sat_critical_reading_avg_score":"353","sat_math_avg_score":"358","sat_writing_avg_score":"340"}\n,{"dbn":"02M305","school_name":"URBAN ASSEMBLY ACADEMY OF GOVERNMENT AND LAW, THE","num_of_sat_test_takers":"50","sat_critical_reading_avg_score":"375","sat_math_avg_score":"388","sat_writing_avg_score":"385"}\n,{"dbn":"02M308","school_name":"LOWER MANHATTAN ARTS ACADEMY","num_of_sat_test_takers":"40","sat_critical_reading_avg_score":"403","sat_math_avg_score":"392","sat_writing_avg_score":"405"}\n,{"dbn":"02M313","school_name":"JAMES BALDWIN SCHOOL, THE: A SCHOOL FOR EXPEDITIONARY LEARNING","num_of_sat_test_takers":"69","sat_critical_reading_avg_score":"408","sat_math_avg_score":"390","sat_writing_avg_score":"390"}\n,{"dbn":"02M316","school_name":"URBAN ASSEMBLY SCHOOL OF BUSINESS FOR YOUNG WOMEN, THE","num_of_sat_test_takers":"42","sat_critical_reading_avg_score":"373","sat_math_avg_score":"370","sat_writing_avg_score":"384"}\n,{"dbn":"02M374","sch ...

# %%
r.json()
# Out:
# [{'dbn': '01M292',
#   'school_name': 'HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES',
#   'num_of_sat_test_takers': '29',
#   'sat_critical_reading_avg_score': '355',
#   'sat_math_avg_score': '404',
#   'sat_writing_avg_score': '363'},
#  {'dbn': '01M448',
#   'school_name': 'UNIVERSITY NEIGHBORHOOD HIGH SCHOOL',
#   'num_of_sat_test_takers': '91',
#   'sat_critical_reading_avg_score': '383',
#   'sat_math_avg_score': '423',
#   'sat_writing_avg_score': '366'},
#  {'dbn': '01M450',
#   'school_name': 'EAST SIDE COMMUNITY SCHOOL',
#   'num_of_sat_test_takers': '70',
#   'sat_critical_reading_avg_score': '377',
#   'sat_math_avg_score': '402',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '01M458',
#   'school_name': 'FORSYTH SATELLITE ACADEMY',
#   'num_of_sat_test_takers': '7',
#   'sat_critical_reading_avg_score': '414',
#   'sat_math_avg_score': '401',
#   'sat_writing_avg_score': '359'},
#  {'dbn': '01M509',
#   'school_name': 'MARTA VALLE HIGH SCHOOL',
#   'num_of_sat_test_takers': '44',
#   'sat_critical_reading_avg_score': '390',
#   'sat_math_avg_score': '433',
#   'sat_writing_avg_score': '384'},
#  {'dbn': '01M515',
#   'school_name': 'LOWER EAST SIDE PREPARATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '112',
#   'sat_critical_reading_avg_score': '332',
#   'sat_math_avg_score': '557',
#   'sat_writing_avg_score': '316'},
#  {'dbn': '01M539',
#   'school_name': 'NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND MATH HIGH SCHOOL',
#   'num_of_sat_test_takers': '159',
#   'sat_critical_reading_avg_score': '522',
#   'sat_math_avg_score': '574',
#   'sat_writing_avg_score': '525'},
#  {'dbn': '01M650',
#   'school_name': 'CASCADES HIGH SCHOOL',
#   'num_of_sat_test_takers': '18',
#   'sat_critical_reading_avg_score': '417',
#   'sat_math_avg_score': '418',
#   'sat_writing_avg_score': '411'},
#  {'dbn': '01M696',
#   'school_name': 'BARD HIGH SCHOOL EARLY COLLEGE',
#   'num_of_sat_test_takers': '130',
#   'sat_critical_reading_avg_score': '624',
#   'sat_math_avg_score': '604',
#   'sat_writing_avg_score': '628'},
#  {'dbn': '02M047',
#   'school_name': '47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '16',
#   'sat_critical_reading_avg_score': '395',
#   'sat_math_avg_score': '400',
#   'sat_writing_avg_score': '387'},
#  {'dbn': '02M288',
#   'school_name': 'FOOD AND FINANCE HIGH SCHOOL',
#   'num_of_sat_test_takers': '62',
#   'sat_critical_reading_avg_score': '409',
#   'sat_math_avg_score': '393',
#   'sat_writing_avg_score': '392'},
#  {'dbn': '02M294',
#   'school_name': 'ESSEX STREET ACADEMY',
#   'num_of_sat_test_takers': '53',
#   'sat_critical_reading_avg_score': '394',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '378'},
#  {'dbn': '02M296',
#   'school_name': 'HIGH SCHOOL OF HOSPITALITY MANAGEMENT',
#   'num_of_sat_test_takers': '58',
#   'sat_critical_reading_avg_score': '374',
#   'sat_math_avg_score': '375',
#   'sat_writing_avg_score': '362'},
#  {'dbn': '02M298',
#   'school_name': 'PACE HIGH SCHOOL',
#   'num_of_sat_test_takers': '85',
#   'sat_critical_reading_avg_score': '423',
#   'sat_math_avg_score': '438',
#   'sat_writing_avg_score': '432'},
#  {'dbn': '02M300',
#   'school_name': 'URBAN ASSEMBLY SCHOOL OF DESIGN AND CONSTRUCTION, THE',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '404',
#   'sat_math_avg_score': '449',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '02M303',
#   'school_name': 'FACING HISTORY SCHOOL, THE',
#   'num_of_sat_test_takers': '76',
#   'sat_critical_reading_avg_score': '353',
#   'sat_math_avg_score': '358',
#   'sat_writing_avg_score': '340'},
#  {'dbn': '02M305',
#   'school_name': 'URBAN ASSEMBLY ACADEMY OF GOVERNMENT AND LAW, THE',
#   'num_of_sat_test_takers': '50',
#   'sat_critical_reading_avg_score': '375',
#   'sat_math_avg_score': '388',
#   'sat_writing_avg_score': '385'},
#  {'dbn': '02M308',
#   'school_name': 'LOWER MANHATTAN ARTS ACADEMY',
#   'num_of_sat_test_takers': '40',
#   'sat_critical_reading_avg_score': '403',
#   'sat_math_avg_score': '392',
#   'sat_writing_avg_score': '405'},
#  {'dbn': '02M313',
#   'school_name': 'JAMES BALDWIN SCHOOL, THE: A SCHOOL FOR EXPEDITIONARY LEARNING',
#   'num_of_sat_test_takers': '69',
#   'sat_critical_reading_avg_score': '408',
#   'sat_math_avg_score': '390',
#   'sat_writing_avg_score': '390'},
#  {'dbn': '02M316',
#   'school_name': 'URBAN ASSEMBLY SCHOOL OF BUSINESS FOR YOUNG WOMEN, THE',
#   'num_of_sat_test_takers': '42',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '370',
#   'sat_writing_avg_score': '384'},
#  {'dbn': '02M374',
#   'school_name': 'GRAMERCY ARTS HIGH SCHOOL',
#   'num_of_sat_test_takers': '60',
#   'sat_critical_reading_avg_score': '391',
#   'sat_math_avg_score': '391',
#   'sat_writing_avg_score': '394'},
#  {'dbn': '02M376',
#   'school_name': 'NYC ISCHOOL',
#   'num_of_sat_test_takers': '92',
#   'sat_critical_reading_avg_score': '473',
#   'sat_math_avg_score': '483',
#   'sat_writing_avg_score': '479'},
#  {'dbn': '02M392',
#   'school_name': 'MANHATTAN BUSINESS ACADEMY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M393',
#   'school_name': 'BUSINESS OF SPORTS SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M394',
#   'school_name': 'EMMA LAZARUS HIGH SCHOOL',
#   'num_of_sat_test_takers': '79',
#   'sat_critical_reading_avg_score': '319',
#   'sat_math_avg_score': '512',
#   'sat_writing_avg_score': '357'},
#  {'dbn': '02M399',
#   'school_name': 'THE HIGH SCHOOL FOR LANGUAGE AND DIPLOMACY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M400',
#   'school_name': 'HIGH SCHOOL FOR ENVIRONMENTAL STUDIES',
#   'num_of_sat_test_takers': '263',
#   'sat_critical_reading_avg_score': '465',
#   'sat_math_avg_score': '493',
#   'sat_writing_avg_score': '461'},
#  {'dbn': '02M407',
#   'school_name': 'INSTITUTE FOR COLLABORATIVE EDUCATION',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '492',
#   'sat_math_avg_score': '465',
#   'sat_writing_avg_score': '467'},
#  {'dbn': '02M408',
#   'school_name': 'PROFESSIONAL PERFORMING ARTS HIGH SCHOOL',
#   'num_of_sat_test_takers': '94',
#   'sat_critical_reading_avg_score': '509',
#   'sat_math_avg_score': '490',
#   'sat_writing_avg_score': '523'},
#  {'dbn': '02M411',
#   'school_name': 'BARUCH COLLEGE CAMPUS HIGH SCHOOL',
#   'num_of_sat_test_takers': '104',
#   'sat_critical_reading_avg_score': '496',
#   'sat_math_avg_score': '563',
#   'sat_writing_avg_score': '518'},
#  {'dbn': '02M412',
#   'school_name': 'N.Y.C. LAB SCHOOL FOR COLLABORATIVE STUDIES',
#   'num_of_sat_test_takers': '114',
#   'sat_critical_reading_avg_score': '537',
#   'sat_math_avg_score': '590',
#   'sat_writing_avg_score': '550'},
#  {'dbn': '02M413',
#   'school_name': 'SCHOOL OF THE FUTURE HIGH SCHOOL',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '517',
#   'sat_math_avg_score': '533',
#   'sat_writing_avg_score': '515'},
#  {'dbn': '02M414',
#   'school_name': 'N.Y.C. MUSEUM SCHOOL',
#   'num_of_sat_test_takers': '103',
#   'sat_critical_reading_avg_score': '468',
#   'sat_math_avg_score': '492',
#   'sat_writing_avg_score': '459'},
#  {'dbn': '02M416',
#   'school_name': 'ELEANOR ROOSEVELT HIGH SCHOOL',
#   'num_of_sat_test_takers': '127',
#   'sat_critical_reading_avg_score': '572',
#   'sat_math_avg_score': '594',
#   'sat_writing_avg_score': '592'},
#  {'dbn': '02M418',
#   'school_name': 'MILLENNIUM HIGH SCHOOL',
#   'num_of_sat_test_takers': '144',
#   'sat_critical_reading_avg_score': '528',
#   'sat_math_avg_score': '553',
#   'sat_writing_avg_score': '533'},
#  {'dbn': '02M419',
#   'school_name': 'LANDMARK HIGH SCHOOL',
#   'num_of_sat_test_takers': '62',
#   'sat_critical_reading_avg_score': '390',
#   'sat_math_avg_score': '399',
#   'sat_writing_avg_score': '381'},
#  {'dbn': '02M420',
#   'school_name': 'HIGH SCHOOL FOR HEALTH PROFESSIONS AND HUMAN SERVICES',
#   'num_of_sat_test_takers': '336',
#   'sat_critical_reading_avg_score': '429',
#   'sat_math_avg_score': '449',
#   'sat_writing_avg_score': '428'},
#  {'dbn': '02M425',
#   'school_name': 'LEADERSHIP AND PUBLIC SERVICE HIGH SCHOOL',
#   'num_of_sat_test_takers': '84',
#   'sat_critical_reading_avg_score': '416',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '02M427',
#   'school_name': 'MANHATTAN ACADEMY FOR ARTS & LANGUAGE',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M429',
#   'school_name': 'LEGACY SCHOOL FOR INTEGRATED STUDIES',
#   'num_of_sat_test_takers': '29',
#   'sat_critical_reading_avg_score': '356',
#   'sat_math_avg_score': '357',
#   'sat_writing_avg_score': '349'},
#  {'dbn': '02M437',
#   'school_name': 'HUDSON HIGH SCHOOL OF LEARNING TECHNOLOGIES',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M438',
#   'school_name': 'INTERNATIONAL HIGH SCHOOL AT UNION SQUARE',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M439',
#   'school_name': 'MANHATTAN VILLAGE ACADEMY',
#   'num_of_sat_test_takers': '95',
#   'sat_critical_reading_avg_score': '441',
#   'sat_math_avg_score': '473',
#   'sat_writing_avg_score': '458'},
#  {'dbn': '02M440',
#   'school_name': 'BAYARD RUSTIN EDUCATIONAL COMPLEX',
#   'num_of_sat_test_takers': '59',
#   'sat_critical_reading_avg_score': '378',
#   'sat_math_avg_score': '365',
#   'sat_writing_avg_score': '368'},
#  {'dbn': '02M449',
#   'school_name': 'VANGUARD HIGH SCHOOL',
#   'num_of_sat_test_takers': '72',
#   'sat_critical_reading_avg_score': '395',
#   'sat_math_avg_score': '416',
#   'sat_writing_avg_score': '388'},
#  {'dbn': '02M459',
#   'school_name': 'MANHATTAN INTERNATIONAL HIGH SCHOOL',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '376',
#   'sat_math_avg_score': '460',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '02M460',
#   'school_name': 'WASHINGTON IRVING HIGH SCHOOL',
#   'num_of_sat_test_takers': '151',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '387',
#   'sat_writing_avg_score': '360'},
#  {'dbn': '02M473',
#   'school_name': 'WASHINGTON IRVING YABC',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M475',
#   'school_name': 'STUYVESANT HIGH SCHOOL',
#   'num_of_sat_test_takers': '832',
#   'sat_critical_reading_avg_score': '679',
#   'sat_math_avg_score': '735',
#   'sat_writing_avg_score': '682'},
#  {'dbn': '02M489',
#   'school_name': 'HIGH SCHOOL OF ECONOMICS AND FINANCE',
#   'num_of_sat_test_takers': '167',
#   'sat_critical_reading_avg_score': '443',
#   'sat_math_avg_score': '489',
#   'sat_writing_avg_score': '442'},
#  {'dbn': '02M500',
#   'school_name': 'UNITY CENTER FOR URBAN TECHNOLOGIES',
#   'num_of_sat_test_takers': '25',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '349',
#   'sat_writing_avg_score': '351'},
#  {'dbn': '02M519',
#   'school_name': 'TALENT UNLIMITED HIGH SCHOOL',
#   'num_of_sat_test_takers': '81',
#   'sat_critical_reading_avg_score': '469',
#   'sat_math_avg_score': '472',
#   'sat_writing_avg_score': '475'},
#  {'dbn': '02M520',
#   'school_name': 'MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS',
#   'num_of_sat_test_takers': '264',
#   'sat_critical_reading_avg_score': '407',
#   'sat_math_avg_score': '440',
#   'sat_writing_avg_score': '393'},
#  {'dbn': '02M529',
#   'school_name': 'JACQUELINE KENNEDY ONASSIS HIGH SCHOOL',
#   'num_of_sat_test_takers': '131',
#   'sat_critical_reading_avg_score': '414',
#   'sat_math_avg_score': '425',
#   'sat_writing_avg_score': '400'},
#  {'dbn': '02M531',
#   'school_name': 'REPERTORY COMPANY HIGH SCHOOL FOR THEATRE ARTS',
#   'num_of_sat_test_takers': '42',
#   'sat_critical_reading_avg_score': '429',
#   'sat_math_avg_score': '404',
#   'sat_writing_avg_score': '420'},
#  {'dbn': '02M542',
#   'school_name': 'MANHATTAN BRIDGES HIGH SCHOOL',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '336',
#   'sat_math_avg_score': '378',
#   'sat_writing_avg_score': '344'},
#  {'dbn': '02M543',
#   'school_name': 'NEW DESIGN HIGH SCHOOL',
#   'num_of_sat_test_takers': '73',
#   'sat_critical_reading_avg_score': '391',
#   'sat_math_avg_score': '395',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '02M544',
#   'school_name': 'INDEPENDENCE HIGH SCHOOL',
#   'num_of_sat_test_takers': '14',
#   'sat_critical_reading_avg_score': '389',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '335'},
#  {'dbn': '02M545',
#   'school_name': 'HIGH SCHOOL FOR DUAL LANGUAGE AND ASIAN STUDIES',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '412',
#   'sat_math_avg_score': '581',
#   'sat_writing_avg_score': '431'},
#  {'dbn': '02M550',
#   'school_name': 'LIBERTY HIGH SCHOOL ACADEMY FOR NEWCOMERS',
#   'num_of_sat_test_takers': '26',
#   'sat_critical_reading_avg_score': '368',
#   'sat_math_avg_score': '436',
#   'sat_writing_avg_score': '352'},
#  {'dbn': '02M551',
#   'school_name': 'THE URBAN ASSEMBLY NEW YORK HARBOR SCHOOL',
#   'num_of_sat_test_takers': '77',
#   'sat_critical_reading_avg_score': '405',
#   'sat_math_avg_score': '423',
#   'sat_writing_avg_score': '384'},
#  {'dbn': '02M560',
#   'school_name': 'HIGH SCHOOL M560 s CITY AS SCHOOL',
#   'num_of_sat_test_takers': '56',
#   'sat_critical_reading_avg_score': '498',
#   'sat_math_avg_score': '440',
#   'sat_writing_avg_score': '477'},
#  {'dbn': '02M565',
#   'school_name': 'URBAN ACADEMY LABORATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '30',
#   'sat_critical_reading_avg_score': '527',
#   'sat_math_avg_score': '508',
#   'sat_writing_avg_score': '512'},
#  {'dbn': '02M570',
#   'school_name': 'SATELLITE ACADEMY HIGH SCHOOL',
#   'num_of_sat_test_takers': '33',
#   'sat_critical_reading_avg_score': '350',
#   'sat_math_avg_score': '337',
#   'sat_writing_avg_score': '345'},
#  {'dbn': '02M575',
#   'school_name': 'MANHATTAN COMPREHENSIVE NIGHT AND DAY HIGH SCHOOL',
#   'num_of_sat_test_takers': '121',
#   'sat_critical_reading_avg_score': '345',
#   'sat_math_avg_score': '517',
#   'sat_writing_avg_score': '343'},
#  {'dbn': '02M580',
#   'school_name': 'RICHARD R. GREEN HIGH SCHOOL OF TEACHING',
#   'num_of_sat_test_takers': '84',
#   'sat_critical_reading_avg_score': '408',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '403'},
#  {'dbn': '02M586',
#   'school_name': 'HARVEY MILK HIGH SCHOOL',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '458',
#   'sat_math_avg_score': '416',
#   'sat_writing_avg_score': '429'},
#  {'dbn': '02M600',
#   'school_name': 'THE HIGH SCHOOL OF FASHION INDUSTRIES',
#   'num_of_sat_test_takers': '335',
#   'sat_critical_reading_avg_score': '423',
#   'sat_math_avg_score': '423',
#   'sat_writing_avg_score': '411'},
#  {'dbn': '02M605',
#   'school_name': 'HUMANITIES PREPARATORY ACADEMY',
#   'num_of_sat_test_takers': '36',
#   'sat_critical_reading_avg_score': '426',
#   'sat_math_avg_score': '403',
#   'sat_writing_avg_score': '426'},
#  {'dbn': '02M615',
#   'school_name': 'CHELSEA CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '83',
#   'sat_critical_reading_avg_score': '399',
#   'sat_math_avg_score': '418',
#   'sat_writing_avg_score': '390'},
#  {'dbn': '02M620',
#   'school_name': 'NORMAN THOMAS HIGH SCHOOL',
#   'num_of_sat_test_takers': '154',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '359'},
#  {'dbn': '02M625',
#   'school_name': 'HIGH SCHOOL OF GRAPHIC COMMUNICATION ARTS',
#   'num_of_sat_test_takers': '191',
#   'sat_critical_reading_avg_score': '395',
#   'sat_math_avg_score': '382',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '02M630',
#   'school_name': 'ART AND DESIGN HIGH SCHOOL',
#   'num_of_sat_test_takers': '270',
#   'sat_critical_reading_avg_score': '444',
#   'sat_math_avg_score': '441',
#   'sat_writing_avg_score': '430'},
#  {'dbn': '02M655',
#   'school_name': 'LIFE SCIENCES SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '409',
#   'sat_math_avg_score': '424',
#   'sat_writing_avg_score': '403'},
#  {'dbn': '03M283',
#   'school_name': 'MANHATTAN THEATRE LAB HIGH SCHOOL',
#   'num_of_sat_test_takers': '27',
#   'sat_critical_reading_avg_score': '406',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '408'},
#  {'dbn': '03M299',
#   'school_name': 'HIGH SCHOOL FOR ARTS, IMAGINATION AND INQUIRY',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '374',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '374'},
#  {'dbn': '03M307',
#   'school_name': 'URBAN ASSEMBLY SCHOOL FOR MEDIA STUDIES, THE',
#   'num_of_sat_test_takers': '41',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '390',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '03M402',
#   'school_name': 'THE URBAN ASSEMBLY SCHOOL FOR GREEN CAREERS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '03M403',
#   'school_name': 'THE GLOBAL LEARNING COLLABORATIVE',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '03M404',
#   'school_name': 'INNOVATION DIPLOMA PLUS',
#   'num_of_sat_test_takers': '12',
#   'sat_critical_reading_avg_score': '416',
#   'sat_math_avg_score': '403',
#   'sat_writing_avg_score': '381'},
#  {'dbn': '03M415',
#   'school_name': 'WADLEIGH SECONDARY SCHOOL FOR THE PERFORMING & VISUAL ARTS',
#   'num_of_sat_test_takers': '32',
#   'sat_critical_reading_avg_score': '371',
#   'sat_math_avg_score': '368',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '03M417',
#   'school_name': 'FRANK MCCOURT HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '03M470',
#   'school_name': 'LOUIS D. BRANDEIS HIGH SCHOOL',
#   'num_of_sat_test_takers': '131',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '390',
#   'sat_writing_avg_score': '358'},
#  {'dbn': '03M479',
#   'school_name': 'BEACON HIGH SCHOOL',
#   'num_of_sat_test_takers': '261',
#   'sat_critical_reading_avg_score': '577',
#   'sat_math_avg_score': '575',
#   'sat_writing_avg_score': '592'},
#  {'dbn': '03M485',
#   'school_name': 'FIORELLO H. LAGUARDIA HIGH SCHOOL OF MUSIC & ART AND PERFORMING ARTS',
#   'num_of_sat_test_takers': '531',
#   'sat_critical_reading_avg_score': '566',
#   'sat_math_avg_score': '564',
#   'sat_writing_avg_score': '577'},
#  {'dbn': '03M492',
#   'school_name': 'HIGH SCHOOL FOR LAW, ADVOCACY AND COMMUNITY JUSTICE',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '396',
#   'sat_math_avg_score': '398',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '03M494',
#   'school_name': 'HIGH SCHOOL OF ARTS AND TECHNOLOGY',
#   'num_of_sat_test_takers': '75',
#   'sat_critical_reading_avg_score': '433',
#   'sat_math_avg_score': '433',
#   'sat_writing_avg_score': '411'},
#  {'dbn': '03M505',
#   'school_name': 'EDWARD A. REYNOLDS WEST SIDE HIGH SCHOOL',
#   'num_of_sat_test_takers': '35',
#   'sat_critical_reading_avg_score': '401',
#   'sat_math_avg_score': '369',
#   'sat_writing_avg_score': '351'},
#  {'dbn': '03M541',
#   'school_name': 'MANHATTAN / HUNTER SCIENCE HIGH SCHOOL',
#   'num_of_sat_test_takers': '111',
#   'sat_critical_reading_avg_score': '473',
#   'sat_math_avg_score': '506',
#   'sat_writing_avg_score': '467'},
#  {'dbn': '03M577',
#   'school_name': 'YOUNG ADULT BOROUGH CENTER AT LOUIS D. BRANDEIS HS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '03M860',
#   'school_name': 'FREDERICK DOUGLASS ACADEMY II SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '43',
#   'sat_critical_reading_avg_score': '356',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '04M409',
#   'school_name': 'COALITION SCHOOL FOR SOCIAL CHANGE',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '354',
#   'sat_math_avg_score': '357',
#   'sat_writing_avg_score': '373'},
#  {'dbn': '04M435',
#   'school_name': 'MANHATTAN CENTER FOR SCIENCE AND MATHEMATICS',
#   'num_of_sat_test_takers': '375',
#   'sat_critical_reading_avg_score': '461',
#   'sat_math_avg_score': '514',
#   'sat_writing_avg_score': '455'},
#  {'dbn': '04M495',
#   'school_name': 'PARK EAST HIGH SCHOOL',
#   'num_of_sat_test_takers': '51',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '04M555',
#   'school_name': 'CENTRAL PARK EAST HIGH SCHOOL',
#   'num_of_sat_test_takers': '73',
#   'sat_critical_reading_avg_score': '405',
#   'sat_math_avg_score': '421',
#   'sat_writing_avg_score': '395'},
#  {'dbn': '04M610',
#   'school_name': "YOUNG WOMEN'S LEADERSHIP SCHOOL",
#   'num_of_sat_test_takers': '70',
#   'sat_critical_reading_avg_score': '432',
#   'sat_math_avg_score': '446',
#   'sat_writing_avg_score': '448'},
#  {'dbn': '04M635',
#   'school_name': 'ACADEMY OF ENVIRONMENTAL SCIENCE SECONDARY HIGH SCHOOL',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '369',
#   'sat_writing_avg_score': '357'},
#  {'dbn': '04M680',
#   'school_name': 'HERITAGE SCHOOL, THE',
#   'num_of_sat_test_takers': '31',
#   'sat_critical_reading_avg_score': '358',
#   'sat_math_avg_score': '351',
#   'sat_writing_avg_score': '345'},
#  {'dbn': '05M285',
#   'school_name': 'HARLEM RENAISSANCE HIGH SCHOOL',
#   'num_of_sat_test_takers': '29',
#   'sat_critical_reading_avg_score': '357',
#   'sat_math_avg_score': '318',
#   'sat_writing_avg_score': '333'},
#  {'dbn': '05M304',
#   'school_name': 'MOTT HALL HIGH SCHOOL',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '413',
#   'sat_math_avg_score': '399',
#   'sat_writing_avg_score': '398'},
#  {'dbn': '05M362',
#   'school_name': 'COLUMBIA SECONDARY SCHOOL FOR MATH, SCIENCE, AND ENGINEERING',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '05M367',
#   'school_name': 'ACADEMY FOR SOCIAL ACTION: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '33',
#   'sat_critical_reading_avg_score': '354',
#   'sat_math_avg_score': '366',
#   'sat_writing_avg_score': '342'},
#  {'dbn': '05M369',
#   'school_name': 'URBAN ASSEMBLY SCHOOL FOR THE PERFORMING ARTS',
#   'num_of_sat_test_takers': '56',
#   'sat_critical_reading_avg_score': '360',
#   'sat_math_avg_score': '353',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '05M469',
#   'school_name': 'CHOIR ACADEMY OF HARLEM',
#   'num_of_sat_test_takers': '20',
#   'sat_critical_reading_avg_score': '354',
#   'sat_math_avg_score': '360',
#   'sat_writing_avg_score': '385'},
#  {'dbn': '05M499',
#   'school_name': 'FREDERICK DOUGLASS ACADEMY',
#   'num_of_sat_test_takers': '214',
#   'sat_critical_reading_avg_score': '458',
#   'sat_math_avg_score': '474',
#   'sat_writing_avg_score': '442'},
#  {'dbn': '05M670',
#   'school_name': 'THURGOOD MARSHALL ACADEMY FOR LEARNING AND SOCIAL CHANGE',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '396',
#   'sat_math_avg_score': '402',
#   'sat_writing_avg_score': '404'},
#  {'dbn': '05M685',
#   'school_name': 'BREAD & ROSES INTEGRATED ARTS HIGH SCHOOL',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '361',
#   'sat_writing_avg_score': '355'},
#  {'dbn': '05M692',
#   'school_name': 'HIGH SCHOOL FOR MATHEMATICS, SCIENCE AND ENGINEERING AT CITY COLLEGE',
#   'num_of_sat_test_takers': '101',
#   'sat_critical_reading_avg_score': '605',
#   'sat_math_avg_score': '654',
#   'sat_writing_avg_score': '588'},
#  {'dbn': '06M293',
#   'school_name': 'CITY COLLEGE ACADEMY OF THE ARTS',
#   'num_of_sat_test_takers': '60',
#   'sat_critical_reading_avg_score': '408',
#   'sat_math_avg_score': '446',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '06M346',
#   'school_name': 'COMMUNITY HEALTH ACADEMY OF THE HEIGHTS',
#   'num_of_sat_test_takers': '55',
#   'sat_critical_reading_avg_score': '362',
#   'sat_math_avg_score': '376',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '06M348',
#   'school_name': 'WASHINGTON HEIGHTS EXPEDITIONARY LEARNING SCHOOL',
#   'num_of_sat_test_takers': '70',
#   'sat_critical_reading_avg_score': '380',
#   'sat_math_avg_score': '395',
#   'sat_writing_avg_score': '399'},
#  {'dbn': '06M423',
#   'school_name': 'HIGH SCHOOL FOR EXCELLENCE AND INNOVATION',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '06M457',
#   'school_name': 'GEORGE WASHINGTON YABC',
#   'num_of_sat_test_takers': '7',
#   'sat_critical_reading_avg_score': '394',
#   'sat_math_avg_score': '357',
#   'sat_writing_avg_score': '346'},
#  {'dbn': '06M462',
#   'school_name': 'HIGH SCHOOL FOR INTERNATIONAL BUSINESS AND FINANCE',
#   'num_of_sat_test_takers': '76',
#   'sat_critical_reading_avg_score': '365',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '378'},
#  {'dbn': '06M463',
#   'school_name': 'HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS',
#   'num_of_sat_test_takers': '63',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '380',
#   'sat_writing_avg_score': '349'},
#  {'dbn': '06M467',
#   'school_name': 'HIGH SCHOOL FOR LAW AND PUBLIC SERVICE',
#   'num_of_sat_test_takers': '94',
#   'sat_critical_reading_avg_score': '363',
#   'sat_math_avg_score': '378',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '06M468',
#   'school_name': 'HIGH SCHOOL FOR HEALTH CAREERS AND SCIENCES',
#   'num_of_sat_test_takers': '24',
#   'sat_critical_reading_avg_score': '400',
#   'sat_math_avg_score': '422',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '06M540',
#   'school_name': 'A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL',
#   'num_of_sat_test_takers': '228',
#   'sat_critical_reading_avg_score': '430',
#   'sat_math_avg_score': '456',
#   'sat_writing_avg_score': '423'},
#  {'dbn': '06M552',
#   'school_name': 'GREGORIO LUPERON HIGH SCHOOL FOR SCIENCE AND MATHEMATICS',
#   'num_of_sat_test_takers': '56',
#   'sat_critical_reading_avg_score': '339',
#   'sat_math_avg_score': '349',
#   'sat_writing_avg_score': '326'},
#  {'dbn': '07X221',
#   'school_name': 'SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '65',
#   'sat_critical_reading_avg_score': '364',
#   'sat_math_avg_score': '378',
#   'sat_writing_avg_score': '348'},
#  {'dbn': '07X321',
#   'school_name': 'CROTONA ACADEMY HIGH SCHOOL',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '379',
#   'sat_math_avg_score': '364',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '07X334',
#   'school_name': 'INTERNATIONAL COMMUNITY HIGH SCHOOL',
#   'num_of_sat_test_takers': '34',
#   'sat_critical_reading_avg_score': '310',
#   'sat_math_avg_score': '324',
#   'sat_writing_avg_score': '311'},
#  {'dbn': '07X379',
#   'school_name': 'JILL CHAIFETZ TRANSFER HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '07X381',
#   'school_name': 'BRONX HAVEN HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '07X427',
#   'school_name': 'COMMUNITY SCHOOL FOR SOCIAL JUSTICE',
#   'num_of_sat_test_takers': '43',
#   'sat_critical_reading_avg_score': '361',
#   'sat_math_avg_score': '359',
#   'sat_writing_avg_score': '357'},
#  {'dbn': '07X473',
#   'school_name': 'MOTT HAVEN VILLAGE PREPARATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '63',
#   'sat_critical_reading_avg_score': '351',
#   'sat_math_avg_score': '375',
#   'sat_writing_avg_score': '371'},
#  {'dbn': '07X495',
#   'school_name': 'UNIVERSITY HEIGHTS SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '79',
#   'sat_critical_reading_avg_score': '403',
#   'sat_math_avg_score': '394',
#   'sat_writing_avg_score': '404'},
#  {'dbn': '07X500',
#   'school_name': 'HOSTOSsLINCOLN ACADEMY OF SCIENCE',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '420',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '411'},
#  {'dbn': '07X520',
#   'school_name': 'FOREIGN LANGUAGE ACADEMY OF GLOBAL STUDIES',
#   'num_of_sat_test_takers': '64',
#   'sat_critical_reading_avg_score': '399',
#   'sat_math_avg_score': '396',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '07X527',
#   'school_name': 'BRONX LEADERSHIP ACADEMY II HIGH SCHOOL',
#   'num_of_sat_test_takers': '62',
#   'sat_critical_reading_avg_score': '362',
#   'sat_math_avg_score': '378',
#   'sat_writing_avg_score': '363'},
#  {'dbn': '07X547',
#   'school_name': 'NEW EXPLORERS HIGH SCHOOL',
#   'num_of_sat_test_takers': '28',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '356',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '07X548',
#   'school_name': 'URBAN ASSEMBLY SCHOOL FOR CAREERS IN SPORTS',
#   'num_of_sat_test_takers': '44',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '411',
#   'sat_writing_avg_score': '383'},
#  {'dbn': '07X551',
#   'school_name': 'BRONX ACADEMY OF LETTERS',
#   'num_of_sat_test_takers': '51',
#   'sat_critical_reading_avg_score': '413',
#   'sat_math_avg_score': '381',
#   'sat_writing_avg_score': '407'},
#  {'dbn': '07X600',
#   'school_name': 'ALFRED E. SMITH CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '76',
#   'sat_critical_reading_avg_score': '394',
#   'sat_math_avg_score': '400',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '07X655',
#   'school_name': 'SAMUEL GOMPERS CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '47',
#   'sat_critical_reading_avg_score': '398',
#   'sat_math_avg_score': '416',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '07X670',
#   'school_name': 'HEALTH OPPORTUNITIES HIGH SCHOOL',
#   'num_of_sat_test_takers': '114',
#   'sat_critical_reading_avg_score': '363',
#   'sat_math_avg_score': '368',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '08X269',
#   'school_name': 'BRONX STUDIO SCHOOL FOR WRITERS AND ARTISTS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X282',
#   'school_name': "WOMEN'S ACADEMY OF EXCELLENCE",
#   'num_of_sat_test_takers': '44',
#   'sat_critical_reading_avg_score': '407',
#   'sat_math_avg_score': '386',
#   'sat_writing_avg_score': '378'},
#  {'dbn': '08X293',
#   'school_name': 'RENAISSANCE HIGH SCHOOL FOR MUSICAL THEATER & TECHNOLOGY',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '385',
#   'sat_writing_avg_score': '389'},
#  {'dbn': '08X295',
#   'school_name': 'GATEWAY SCHOOL FOR ENVIRONMENTAL RESEARCH AND TECHNOLOGY',
#   'num_of_sat_test_takers': '41',
#   'sat_critical_reading_avg_score': '416',
#   'sat_math_avg_score': '390',
#   'sat_writing_avg_score': '394'},
#  {'dbn': '08X305',
#   'school_name': 'PABLO NERUDA ACADEMY FOR ARCHITECTURE AND WORLD STUDIES',
#   'num_of_sat_test_takers': '67',
#   'sat_critical_reading_avg_score': '337',
#   'sat_math_avg_score': '361',
#   'sat_writing_avg_score': '340'},
#  {'dbn': '08X312',
#   'school_name': 'MILLENNIUM ART ACADEMY',
#   'num_of_sat_test_takers': '67',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '402',
#   'sat_writing_avg_score': '375'},
#  {'dbn': '08X332',
#   'school_name': 'HOLCOMBE L. RUCKER SCHOOL OF COMMUNITY RESEARCH',
#   'num_of_sat_test_takers': '39',
#   'sat_critical_reading_avg_score': '363',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '350'},
#  {'dbn': '08X367',
#   'school_name': 'ARCHIMEDES ACADEMY FOR MATH, SCIENCE AND TECHNOLOGY APPLICATIONS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X376',
#   'school_name': 'ANTONIA PANTOJA PREPARATORY ACADEMY, A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X377',
#   'school_name': 'BRONX COMMUNITY HIGH SCHOOL',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '369',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '08X405',
#   'school_name': 'HERBERT H. LEHMAN HIGH SCHOOL',
#   'num_of_sat_test_takers': '415',
#   'sat_critical_reading_avg_score': '412',
#   'sat_math_avg_score': '436',
#   'sat_writing_avg_score': '393'},
#  {'dbn': '08X408',
#   'school_name': 'HERBERT H. LEHMAN YABC',
#   'num_of_sat_test_takers': '6',
#   'sat_critical_reading_avg_score': '402',
#   'sat_math_avg_score': '373',
#   'sat_writing_avg_score': '413'},
#  {'dbn': '08X432',
#   'school_name': 'BRONX BRIDGES HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X452',
#   'school_name': 'BRONX GUILD',
#   'num_of_sat_test_takers': '39',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '365'},
#  {'dbn': '08X507',
#   'school_name': 'STEVENSON YABC',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X519',
#   'school_name': 'FELISA RINCON DE GAUTIER INSTITUTE FOR LAW AND PUBLIC POLICY, THE',
#   'num_of_sat_test_takers': '68',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '370',
#   'sat_writing_avg_score': '356'},
#  {'dbn': '08X530',
#   'school_name': 'BANANA KELLY HIGH SCHOOL',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '381',
#   'sat_writing_avg_score': '377'},
#  {'dbn': '08X537',
#   'school_name': 'BRONX ARENA HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X540',
#   'school_name': 'SCHOOL FOR COMMUNITY RESEARCH AND LEARNING',
#   'num_of_sat_test_takers': '16',
#   'sat_critical_reading_avg_score': '366',
#   'sat_math_avg_score': '400',
#   'sat_writing_avg_score': '368'},
#  {'dbn': '08X560',
#   'school_name': 'HIGH SCHOOL X560 s BRONX ACADEMY HIGH SCHOOL',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '404',
#   'sat_math_avg_score': '368',
#   'sat_writing_avg_score': '399'},
#  {'dbn': '08X650',
#   'school_name': 'JANE ADDAMS HIGH SCHOOL FOR ACADEMIC CAREERS',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '377',
#   'sat_math_avg_score': '359',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '09X227',
#   'school_name': 'BRONX EXPEDITIONARY LEARNING HIGH SCHOOL',
#   'num_of_sat_test_takers': '39',
#   'sat_critical_reading_avg_score': '324',
#   'sat_math_avg_score': '376',
#   'sat_writing_avg_score': '349'},
#  {'dbn': '09X231',
#   'school_name': 'EAGLE ACADEMY FOR YOUNG MEN',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '387',
#   'sat_writing_avg_score': '374'},
#  {'dbn': '09X239',
#   'school_name': 'URBAN ASSEMBLY ACADEMY FOR HISTORY AND CITIZENSHIP FOR YOUNG MEN, THE',
#   'num_of_sat_test_takers': '33',
#   'sat_critical_reading_avg_score': '372',
#   'sat_math_avg_score': '355',
#   'sat_writing_avg_score': '357'},
#  {'dbn': '09X241',
#   'school_name': 'URBAN ASSEMBLY SCHOOL FOR APPLIED MATH AND SCIENCE, THE',
#   'num_of_sat_test_takers': '80',
#   'sat_critical_reading_avg_score': '411',
#   'sat_math_avg_score': '464',
#   'sat_writing_avg_score': '415'},
#  {'dbn': '09X250',
#   'school_name': 'EXIMIUS COLLEGE PREPARATORY ACADEMY: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '50',
#   'sat_critical_reading_avg_score': '393',
#   'sat_math_avg_score': '394',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '09X252',
#   'school_name': 'MOTT HALL BRONX HIGH SCHOOL',
#   'num_of_sat_test_takers': '67',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '367',
#   'sat_writing_avg_score': '356'},
#  {'dbn': '09X260',
#   'school_name': 'BRONX CENTER FOR SCIENCE AND MATHEMATICS',
#   'num_of_sat_test_takers': '81',
#   'sat_critical_reading_avg_score': '459',
#   'sat_math_avg_score': '480',
#   'sat_writing_avg_score': '457'},
#  {'dbn': '09X263',
#   'school_name': 'VALIDUS PREPARATORY ACADEMY: AN EXPEDITIONARY LEARNING SCHOOL',
#   'num_of_sat_test_takers': '74',
#   'sat_critical_reading_avg_score': '356',
#   'sat_math_avg_score': '363',
#   'sat_writing_avg_score': '356'},
#  {'dbn': '09X276',
#   'school_name': 'LEADERSHIP INSTITUTE',
#   'num_of_sat_test_takers': '30',
#   'sat_critical_reading_avg_score': '361',
#   'sat_math_avg_score': '353',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '09X297',
#   'school_name': 'MORRIS ACADEMY FOR COLLABORATIVE STUDIES',
#   'num_of_sat_test_takers': '38',
#   'sat_critical_reading_avg_score': '386',
#   'sat_math_avg_score': '386',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '09X324',
#   'school_name': 'BRONX EARLY COLLEGE ACADEMY FOR TEACHING & LEARNING',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '09X329',
#   'school_name': 'DREAMYARD PREPARATORY SCHOOL',
#   'num_of_sat_test_takers': '51',
#   'sat_critical_reading_avg_score': '382',
#   'sat_math_avg_score': '365',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '09X365',
#   'school_name': 'ACADEMY FOR LANGUAGE AND TECHNOLOGY',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '315',
#   'sat_math_avg_score': '339',
#   'sat_writing_avg_score': '297'},
#  {'dbn': '09X403',
#   'school_name': 'BRONX INTERNATIONAL HIGH SCHOOL',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '314',
#   'sat_math_avg_score': '312',
#   'sat_writing_avg_score': '339'},
#  {'dbn': '09X404',
#   'school_name': 'SCHOOL FOR EXCELLENCE',
#   'num_of_sat_test_takers': '32',
#   'sat_critical_reading_avg_score': '363',
#   'sat_math_avg_score': '360',
#   'sat_writing_avg_score': '351'},
#  {'dbn': '09X412',
#   'school_name': 'BRONX HIGH SCHOOL OF BUSINESS',
#   'num_of_sat_test_takers': '34',
#   'sat_critical_reading_avg_score': '356',
#   'sat_math_avg_score': '376',
#   'sat_writing_avg_score': '351'},
#  {'dbn': '09X413',
#   'school_name': 'BRONX HIGH SCHOOL FOR MEDICAL SCIENCE',
#   'num_of_sat_test_takers': '64',
#   'sat_critical_reading_avg_score': '400',
#   'sat_math_avg_score': '419',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '09X414',
#   'school_name': 'JONATHAN LEVIN HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS',
#   'num_of_sat_test_takers': '35',
#   'sat_critical_reading_avg_score': '379',
#   'sat_math_avg_score': '364',
#   'sat_writing_avg_score': '379'},
#  {'dbn': '09X505',
#   'school_name': 'BRONX SCHOOL FOR LAW, GOVERNMENT AND JUSTICE',
#   'num_of_sat_test_takers': '80',
#   'sat_critical_reading_avg_score': '404',
#   'sat_math_avg_score': '418',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '09X517',
#   'school_name': 'FREDERICK DOUGLASS ACADEMY III SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '50',
#   'sat_critical_reading_avg_score': '368',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '369'},
#  {'dbn': '09X525',
#   'school_name': 'BRONX LEADERSHIP ACADEMY HIGH SCHOOL',
#   'num_of_sat_test_takers': '114',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '394',
#   'sat_writing_avg_score': '388'},
#  {'dbn': '09X543',
#   'school_name': 'HIGH SCHOOL FOR VIOLIN AND DANCE',
#   'num_of_sat_test_takers': '27',
#   'sat_critical_reading_avg_score': '353',
#   'sat_math_avg_score': '315',
#   'sat_writing_avg_score': '371'},
#  {'dbn': '10X141',
#   'school_name': 'RIVERDALE / KINGSBRIDGE ACADEMY (MIDDLE SCHOOL / HIGH SCHOOL 141)',
#   'num_of_sat_test_takers': '113',
#   'sat_critical_reading_avg_score': '438',
#   'sat_math_avg_score': '455',
#   'sat_writing_avg_score': '440'},
#  {'dbn': '10X213',
#   'school_name': 'BRONX ENGINEERING AND TECHNOLOGY ACADEMY',
#   'num_of_sat_test_takers': '86',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '412',
#   'sat_writing_avg_score': '365'},
#  {'dbn': '10X225',
#   'school_name': 'THEATRE ARTS PRODUCTION COMPANY SCHOOL',
#   'num_of_sat_test_takers': '59',
#   'sat_critical_reading_avg_score': '405',
#   'sat_math_avg_score': '391',
#   'sat_writing_avg_score': '394'},
#  {'dbn': '10X237',
#   'school_name': 'THE MARIE CURIE SCHOOL FOR MEDICINE, NURSING, AND HEALTH PROFESSIONS',
#   'num_of_sat_test_takers': '79',
#   'sat_critical_reading_avg_score': '382',
#   'sat_math_avg_score': '393',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '10X243',
#   'school_name': 'WEST BRONX ACADEMY FOR THE FUTURE',
#   'num_of_sat_test_takers': '26',
#   'sat_critical_reading_avg_score': '382',
#   'sat_math_avg_score': '406',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '10X268',
#   'school_name': 'KINGSBRIDGE INTERNATIONAL HIGH SCHOOL',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '304',
#   'sat_math_avg_score': '356',
#   'sat_writing_avg_score': '302'},
#  {'dbn': '10X284',
#   'school_name': 'BRONX SCHOOL OF LAW AND FINANCE',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '402',
#   'sat_math_avg_score': '395',
#   'sat_writing_avg_score': '385'},
#  {'dbn': '10X319',
#   'school_name': 'PROVIDING URBAN LEARNERS SUCCESS IN EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '10X342',
#   'school_name': 'INTERNATIONAL SCHOOL FOR LIBERAL ARTS',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '300',
#   'sat_math_avg_score': '333',
#   'sat_writing_avg_score': '301'},
#  {'dbn': '10X368',
#   'school_name': 'INsTECH ACADEMY (M.S. / HIGH SCHOOL 368)',
#   'num_of_sat_test_takers': '111',
#   'sat_critical_reading_avg_score': '390',
#   'sat_math_avg_score': '408',
#   'sat_writing_avg_score': '383'},
#  {'dbn': '10X374',
#   'school_name': 'KNOWLEDGE AND POWER PREPARATORY ACADEMY INTERNATIONAL HIGH SCHOOL (KAPPA)',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '392',
#   'sat_math_avg_score': '401',
#   'sat_writing_avg_score': '387'},
#  {'dbn': '10X397',
#   'school_name': 'ENGLISH LANGUAGE LEARNERS AND INTERNATIONAL SUPPORT PREPARATORY ACADEMY (ELLIS)',
#   'num_of_sat_test_takers': '38',
#   'sat_critical_reading_avg_score': '343',
#   'sat_math_avg_score': '356',
#   'sat_writing_avg_score': '330'},
#  {'dbn': '10X433',
#   'school_name': 'HIGH SCHOOL FOR TEACHING AND THE PROFESSIONS',
#   'num_of_sat_test_takers': '57',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '365'},
#  {'dbn': '10X434',
#   'school_name': 'BELMONT PREPARATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '51',
#   'sat_critical_reading_avg_score': '404',
#   'sat_math_avg_score': '418',
#   'sat_writing_avg_score': '400'},
#  {'dbn': '10X437',
#   'school_name': 'FORDHAM HIGH SCHOOL FOR THE ARTS',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '355',
#   'sat_math_avg_score': '350',
#   'sat_writing_avg_score': '372'},
#  {'dbn': '10X438',
#   'school_name': 'FORDHAM LEADERSHIP ACADEMY FOR BUSINESS AND TECHNOLOGY',
#   'num_of_sat_test_takers': '63',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '385',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '10X439',
#   'school_name': 'BRONX HIGH SCHOOL FOR LAW AND COMMUNITY SERVICE',
#   'num_of_sat_test_takers': '65',
#   'sat_critical_reading_avg_score': '366',
#   'sat_math_avg_score': '364',
#   'sat_writing_avg_score': '352'},
#  {'dbn': '10X440',
#   'school_name': 'DEWITT CLINTON HIGH SCHOOL',
#   'num_of_sat_test_takers': '443',
#   'sat_critical_reading_avg_score': '419',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '410'},
#  {'dbn': '10X442',
#   'school_name': 'CELIA CRUZ BRONX HIGH SCHOOL OF MUSIC, THE',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '423',
#   'sat_math_avg_score': '420',
#   'sat_writing_avg_score': '427'},
#  {'dbn': '10X445',
#   'school_name': 'BRONX HIGH SCHOOL OF SCIENCE',
#   'num_of_sat_test_takers': '731',
#   'sat_critical_reading_avg_score': '632',
#   'sat_math_avg_score': '688',
#   'sat_writing_avg_score': '649'},
#  {'dbn': '10X475',
#   'school_name': 'JOHN F. KENNEDY HIGH SCHOOL',
#   'num_of_sat_test_takers': '109',
#   'sat_critical_reading_avg_score': '351',
#   'sat_math_avg_score': '362',
#   'sat_writing_avg_score': '339'},
#  {'dbn': '10X477',
#   'school_name': 'MARBLE HILL HIGH SCHOOL FOR INTERNATIONAL STUDIES',
#   'num_of_sat_test_takers': '99',
#   'sat_critical_reading_avg_score': '414',
#   'sat_math_avg_score': '435',
#   'sat_writing_avg_score': '414'},
#  {'dbn': '10X478',
#   'school_name': 'LEARNING TO WORK GED AT JOHN F. KENNEDY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '10X546',
#   'school_name': 'BRONX THEATRE HIGH SCHOOL',
#   'num_of_sat_test_takers': '68',
#   'sat_critical_reading_avg_score': '348',
#   'sat_math_avg_score': '362',
#   'sat_writing_avg_score': '354'},
#  {'dbn': '10X549',
#   'school_name': 'DISCOVERY HIGH SCHOOL',
#   'num_of_sat_test_takers': '55',
#   'sat_critical_reading_avg_score': '372',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '10X660',
#   'school_name': 'GRACE DODGE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '73',
#   'sat_critical_reading_avg_score': '362',
#   'sat_math_avg_score': '382',
#   'sat_writing_avg_score': '356'},
#  {'dbn': '10X667',
#   'school_name': 'GRACE DODGE YABC',
#   'num_of_sat_test_takers': '10',
#   'sat_critical_reading_avg_score': '350',
#   'sat_math_avg_score': '356',
#   'sat_writing_avg_score': '317'},
#  {'dbn': '10X696',
#   'school_name': 'HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE',
#   'num_of_sat_test_takers': '92',
#   'sat_critical_reading_avg_score': '636',
#   'sat_math_avg_score': '648',
#   'sat_writing_avg_score': '636'},
#  {'dbn': '11X249',
#   'school_name': 'BRONX HEALTH SCIENCES HIGH SCHOOL',
#   'num_of_sat_test_takers': '74',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '381',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '11X253',
#   'school_name': 'BRONX HIGH SCHOOL FOR WRITING AND COMMUNICATION ARTS',
#   'num_of_sat_test_takers': '46',
#   'sat_critical_reading_avg_score': '400',
#   'sat_math_avg_score': '357',
#   'sat_writing_avg_score': '390'},
#  {'dbn': '11X265',
#   'school_name': 'BRONX LAB SCHOOL',
#   'num_of_sat_test_takers': '81',
#   'sat_critical_reading_avg_score': '377',
#   'sat_math_avg_score': '391',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '11X270',
#   'school_name': 'ACADEMY FOR SCHOLARSHIP AND ENTREPRENEURSHIP: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '56',
#   'sat_critical_reading_avg_score': '386',
#   'sat_math_avg_score': '394',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '11X275',
#   'school_name': 'HIGH SCHOOL OF COMPUTERS AND TECHNOLOGY',
#   'num_of_sat_test_takers': '72',
#   'sat_critical_reading_avg_score': '381',
#   'sat_math_avg_score': '376',
#   'sat_writing_avg_score': '354'},
#  {'dbn': '11X288',
#   'school_name': 'COLLEGIATE INSTITUTE FOR MATH AND SCIENCE',
#   'num_of_sat_test_takers': '97',
#   'sat_critical_reading_avg_score': '444',
#   'sat_math_avg_score': '471',
#   'sat_writing_avg_score': '433'},
#  {'dbn': '11X290',
#   'school_name': 'BRONX ACADEMY OF HEALTH CAREERS',
#   'num_of_sat_test_takers': '69',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '365',
#   'sat_writing_avg_score': '383'},
#  {'dbn': '11X299',
#   'school_name': 'ASTOR COLLEGIATE ACADEMY',
#   'num_of_sat_test_takers': '60',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '391',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '11X415',
#   'school_name': 'CHRISTOPHER COLUMBUS HIGH SCHOOL',
#   'num_of_sat_test_takers': '121',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '361',
#   'sat_writing_avg_score': '353'},
#  {'dbn': '11X417',
#   'school_name': 'YOUNG ADULT BOROUGH CNTR CHRISTOPHER COLUMBUS HS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '11X418',
#   'school_name': 'BRONX HIGH SCHOOL FOR THE VISUAL ARTS',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '419',
#   'sat_math_avg_score': '433',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '11X455',
# ...
#   'sat_math_avg_score': '434',
#   'sat_writing_avg_score': '420'},
#  {'dbn': '27Q260',
#   'school_name': 'FREDERICK DOUGLASS ACADEMY VI HIGH SCHOOL',
#   'num_of_sat_test_takers': '87',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '385',
#   'sat_writing_avg_score': '373'},
#  {'dbn': '27Q262',
#   'school_name': 'CHANNEL VIEW SCHOOL FOR RESEARCH',
#   'num_of_sat_test_takers': '74',
#   'sat_critical_reading_avg_score': '432',
#   'sat_math_avg_score': '419',
#   'sat_writing_avg_score': '401'},
#  {'dbn': '27Q302',
#   'school_name': 'QUEENS HIGH SCHOOL FOR INFORMATION, RESEARCH, AND TECHNOLOGY',
#   'num_of_sat_test_takers': '44',
#   'sat_critical_reading_avg_score': '391',
#   'sat_math_avg_score': '401',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '27Q308',
#   'school_name': 'ROBERT H. GODDARD HIGH SCHOOL OF COMMUNICATION ARTS AND TECHNOLOGY',
#   'num_of_sat_test_takers': '93',
#   'sat_critical_reading_avg_score': '423',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '27Q309',
#   'school_name': 'ACADEMY OF MEDICAL TECHNOLOGY: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '36',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '348'},
#  {'dbn': '27Q323',
#   'school_name': "SCHOLARS' ACADEMY",
#   'num_of_sat_test_takers': '89',
#   'sat_critical_reading_avg_score': '499',
#   'sat_math_avg_score': '537',
#   'sat_writing_avg_score': '496'},
#  {'dbn': '27Q400',
#   'school_name': 'AUGUST MARTIN HIGH SCHOOL',
#   'num_of_sat_test_takers': '101',
#   'sat_critical_reading_avg_score': '377',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '360'},
#  {'dbn': '27Q410',
#   'school_name': 'BEACH CHANNEL HIGH SCHOOL',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '396',
#   'sat_writing_avg_score': '354'},
#  {'dbn': '27Q475',
#   'school_name': 'RICHMOND HILL HIGH SCHOOL',
#   'num_of_sat_test_takers': '404',
#   'sat_critical_reading_avg_score': '382',
#   'sat_math_avg_score': '404',
#   'sat_writing_avg_score': '368'},
#  {'dbn': '27Q480',
#   'school_name': 'JOHN ADAMS HIGH SCHOOL',
#   'num_of_sat_test_takers': '403',
#   'sat_critical_reading_avg_score': '391',
#   'sat_math_avg_score': '409',
#   'sat_writing_avg_score': '392'},
#  {'dbn': '27Q650',
#   'school_name': 'HIGH SCHOOL FOR CONSTRUCTION TRADES, ENGINEERING AND ARCHITECTURE',
#   'num_of_sat_test_takers': '194',
#   'sat_critical_reading_avg_score': '429',
#   'sat_math_avg_score': '491',
#   'sat_writing_avg_score': '425'},
#  {'dbn': '28Q284',
#   'school_name': 'YORK EARLY COLLEGE ACADEMY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '28Q310',
#   'school_name': 'QUEENS COLLEGIATE: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '68',
#   'sat_critical_reading_avg_score': '420',
#   'sat_math_avg_score': '445',
#   'sat_writing_avg_score': '400'},
#  {'dbn': '28Q325',
#   'school_name': 'HILLSIDE ARTS & LETTERS ACADEMY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '28Q338',
#   'school_name': 'QUEENS SATELLITE HIGH SCHOOL FOR OPPORTUNITY',
#   'num_of_sat_test_takers': '6',
#   'sat_critical_reading_avg_score': '403',
#   'sat_math_avg_score': '408',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '28Q350',
#   'school_name': 'JAMAICA GATEWAY TO THE SCIENCES',
#   'num_of_sat_test_takers': '25',
#   'sat_critical_reading_avg_score': '430',
#   'sat_math_avg_score': '452',
#   'sat_writing_avg_score': '425'},
#  {'dbn': '28Q440',
#   'school_name': 'FOREST HILLS HIGH SCHOOL',
#   'num_of_sat_test_takers': '762',
#   'sat_critical_reading_avg_score': '456',
#   'sat_math_avg_score': '497',
#   'sat_writing_avg_score': '454'},
#  {'dbn': '28Q470',
#   'school_name': 'JAMAICA HIGH SCHOOL',
#   'num_of_sat_test_takers': '90',
#   'sat_critical_reading_avg_score': '342',
#   'sat_math_avg_score': '368',
#   'sat_writing_avg_score': '353'},
#  {'dbn': '28Q505',
#   'school_name': 'HILLCREST HIGH SCHOOL',
#   'num_of_sat_test_takers': '462',
#   'sat_critical_reading_avg_score': '395',
#   'sat_math_avg_score': '413',
#   'sat_writing_avg_score': '386'},
#  {'dbn': '28Q620',
#   'school_name': 'THOMAS A. EDISON CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '422',
#   'sat_critical_reading_avg_score': '452',
#   'sat_math_avg_score': '478',
#   'sat_writing_avg_score': '442'},
#  {'dbn': '28Q680',
#   'school_name': 'QUEENS GATEWAY TO HEALTH SCIENCES SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '99',
#   'sat_critical_reading_avg_score': '513',
#   'sat_math_avg_score': '523',
#   'sat_writing_avg_score': '502'},
#  {'dbn': '28Q686',
#   'school_name': 'QUEENS METROPOLITAN HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '28Q687',
#   'school_name': 'QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK COLLEGE',
#   'num_of_sat_test_takers': '121',
#   'sat_critical_reading_avg_score': '612',
#   'sat_math_avg_score': '660',
#   'sat_writing_avg_score': '596'},
#  {'dbn': '28Q690',
#   'school_name': 'HIGH SCHOOL FOR LAW ENFORCEMENT AND PUBLIC SAFETY',
#   'num_of_sat_test_takers': '74',
#   'sat_critical_reading_avg_score': '406',
#   'sat_math_avg_score': '406',
#   'sat_writing_avg_score': '384'},
#  {'dbn': '28Q896',
#   'school_name': "YOUNG WOMEN'S LEADERSHIP SCHOOL, QUEENS",
#   'num_of_sat_test_takers': '68',
#   'sat_critical_reading_avg_score': '439',
#   'sat_math_avg_score': '445',
#   'sat_writing_avg_score': '432'},
#  {'dbn': '29Q248',
#   'school_name': 'QUEENS PREPARATORY ACADEMY',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '360',
#   'sat_math_avg_score': '380',
#   'sat_writing_avg_score': '359'},
#  {'dbn': '29Q259',
#   'school_name': 'PATHWAYS COLLEGE PREPARATORY SCHOOL: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '46',
#   'sat_critical_reading_avg_score': '401',
#   'sat_math_avg_score': '397',
#   'sat_writing_avg_score': '375'},
#  {'dbn': '29Q265',
#   'school_name': 'EXCELSIOR PREPARATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '402',
#   'sat_math_avg_score': '398',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '29Q272',
#   'school_name': 'GEORGE WASHINGTON CARVER HIGH SCHOOL FOR THE SCIENCES',
#   'num_of_sat_test_takers': '59',
#   'sat_critical_reading_avg_score': '436',
#   'sat_math_avg_score': '427',
#   'sat_writing_avg_score': '424'},
#  {'dbn': '29Q283',
#   'school_name': 'PREPARATORY ACADEMY FOR WRITERS: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '43',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '367',
#   'sat_writing_avg_score': '363'},
#  {'dbn': '29Q326',
#   'school_name': 'CAMBRIA HEIGHTS ACADEMY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '29Q492',
#   'school_name': 'MATHEMATICS, SCIENCE RESEARCH AND TECHNOLOGY MAGNET HIGH SCHOOL',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '400',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '394'},
#  {'dbn': '29Q494',
#   'school_name': 'LAW, GOVERNMENT AND COMMUNITY SERVICE HIGH SCHOOL',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '385',
#   'sat_math_avg_score': '377',
#   'sat_writing_avg_score': '377'},
#  {'dbn': '29Q496',
#   'school_name': 'BUSINESS, COMPUTER APPLICATIONS & ENTREPRENEURSHIP HIGH SCHOOL',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '379',
#   'sat_math_avg_score': '414',
#   'sat_writing_avg_score': '359'},
#  {'dbn': '29Q498',
#   'school_name': 'HUMANITIES & ARTS MAGNET HIGH SCHOOL',
#   'num_of_sat_test_takers': '62',
#   'sat_critical_reading_avg_score': '393',
#   'sat_math_avg_score': '381',
#   'sat_writing_avg_score': '377'},
#  {'dbn': '30Q286',
#   'school_name': "YOUNG WOMEN'S LEADERSHIP SCHOOL, ASTORIA",
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '30Q301',
#   'school_name': 'ACADEMY FOR CAREERS IN TELEVISION AND FILM',
#   'num_of_sat_test_takers': '98',
#   'sat_critical_reading_avg_score': '410',
#   'sat_math_avg_score': '440',
#   'sat_writing_avg_score': '405'},
#  {'dbn': '30Q445',
#   'school_name': 'WILLIAM CULLEN BRYANT HIGH SCHOOL',
#   'num_of_sat_test_takers': '395',
#   'sat_critical_reading_avg_score': '414',
#   'sat_math_avg_score': '449',
#   'sat_writing_avg_score': '412'},
#  {'dbn': '30Q450',
#   'school_name': 'LONG ISLAND CITY HIGH SCHOOL',
#   'num_of_sat_test_takers': '392',
#   'sat_critical_reading_avg_score': '403',
#   'sat_math_avg_score': '420',
#   'sat_writing_avg_score': '395'},
#  {'dbn': '30Q501',
#   'school_name': 'FRANK SINATRA SCHOOL OF THE ARTS HIGH SCHOOL',
#   'num_of_sat_test_takers': '174',
#   'sat_critical_reading_avg_score': '504',
#   'sat_math_avg_score': '496',
#   'sat_writing_avg_score': '494'},
#  {'dbn': '30Q502',
#   'school_name': 'INFORMATION TECHNOLOGY HIGH SCHOOL',
#   'num_of_sat_test_takers': '148',
#   'sat_critical_reading_avg_score': '407',
#   'sat_math_avg_score': '434',
#   'sat_writing_avg_score': '398'},
#  {'dbn': '30Q555',
#   'school_name': 'NEWCOMERS HIGH SCHOOL',
#   'num_of_sat_test_takers': '143',
#   'sat_critical_reading_avg_score': '323',
#   'sat_math_avg_score': '475',
#   'sat_writing_avg_score': '329'},
#  {'dbn': '30Q575',
#   'school_name': 'ACADEMY OF AMERICAN STUDIES',
#   'num_of_sat_test_takers': '135',
#   'sat_critical_reading_avg_score': '487',
#   'sat_math_avg_score': '492',
#   'sat_writing_avg_score': '491'},
#  {'dbn': '30Q580',
#   'school_name': 'BACCALAUREATE SCHOOL FOR GLOBAL EDUCATION',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '524',
#   'sat_math_avg_score': '568',
#   'sat_writing_avg_score': '544'},
#  {'dbn': '31R047',
#   'school_name': 'CSI HIGH SCHOOL FOR INTERNATIONAL STUDIES',
#   'num_of_sat_test_takers': '137',
#   'sat_critical_reading_avg_score': '452',
#   'sat_math_avg_score': '451',
#   'sat_writing_avg_score': '450'},
#  {'dbn': '31R064',
#   'school_name': 'GAYNOR MCCOWN EXPEDITIONARY LEARNING SCHOOL',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '398',
#   'sat_math_avg_score': '412',
#   'sat_writing_avg_score': '385'},
#  {'dbn': '31R080',
#   'school_name': 'THE MICHAEL J. PETRIDES SCHOOL',
#   'num_of_sat_test_takers': '107',
#   'sat_critical_reading_avg_score': '472',
#   'sat_math_avg_score': '488',
#   'sat_writing_avg_score': '466'},
#  {'dbn': '31R440',
#   'school_name': 'NEW DORP HIGH SCHOOL',
#   'num_of_sat_test_takers': '391',
#   'sat_critical_reading_avg_score': '424',
#   'sat_math_avg_score': '437',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '31R445',
#   'school_name': 'PORT RICHMOND HIGH SCHOOL',
#   'num_of_sat_test_takers': '271',
#   'sat_critical_reading_avg_score': '424',
#   'sat_math_avg_score': '438',
#   'sat_writing_avg_score': '417'},
#  {'dbn': '31R450',
#   'school_name': 'CURTIS HIGH SCHOOL',
#   'num_of_sat_test_takers': '375',
#   'sat_critical_reading_avg_score': '437',
#   'sat_math_avg_score': '435',
#   'sat_writing_avg_score': '429'},
#  {'dbn': '31R455',
#   'school_name': 'TOTTENVILLE HIGH SCHOOL',
#   'num_of_sat_test_takers': '807',
#   'sat_critical_reading_avg_score': '462',
#   'sat_math_avg_score': '486',
#   'sat_writing_avg_score': '470'},
#  {'dbn': '31R460',
#   'school_name': 'SUSAN E. WAGNER HIGH SCHOOL',
#   'num_of_sat_test_takers': '535',
#   'sat_critical_reading_avg_score': '455',
#   'sat_math_avg_score': '474',
#   'sat_writing_avg_score': '459'},
#  {'dbn': '31R470',
#   'school_name': 'CONCORD HIGH SCHOOL',
#   'num_of_sat_test_takers': '10',
#   'sat_critical_reading_avg_score': '466',
#   'sat_math_avg_score': '455',
#   'sat_writing_avg_score': '414'},
#  {'dbn': '31R600',
#   'school_name': 'RALPH R. MCKEE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '94',
#   'sat_critical_reading_avg_score': '416',
#   'sat_math_avg_score': '422',
#   'sat_writing_avg_score': '397'},
#  {'dbn': '31R605',
#   'school_name': 'STATEN ISLAND TECHNICAL HIGH SCHOOL',
#   'num_of_sat_test_takers': '227',
#   'sat_critical_reading_avg_score': '635',
#   'sat_math_avg_score': '682',
#   'sat_writing_avg_score': '636'},
#  {'dbn': '31R607',
#   'school_name': 'YOUNG ADULT BOROUGH CENTER AT STATEN IS TECH HS',
#   'num_of_sat_test_takers': '10',
#   'sat_critical_reading_avg_score': '405',
#   'sat_math_avg_score': '375',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '32K403',
#   'school_name': 'ACADEMY FOR ENVIRONMENTAL LEADERSHIP',
#   'num_of_sat_test_takers': '50',
#   'sat_critical_reading_avg_score': '380',
#   'sat_math_avg_score': '366',
#   'sat_writing_avg_score': '352'},
#  {'dbn': '32K545',
#   'school_name': 'EBC HIGH SCHOOL FOR PUBLIC SERVICE–BUSHWICK',
#   'num_of_sat_test_takers': '88',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '409',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '32K549',
#   'school_name': 'BUSHWICK SCHOOL FOR SOCIAL JUSTICE',
#   'num_of_sat_test_takers': '75',
#   'sat_critical_reading_avg_score': '348',
#   'sat_math_avg_score': '353',
#   'sat_writing_avg_score': '334'},
#  {'dbn': '32K552',
#   'school_name': 'ACADEMY OF URBAN PLANNING',
#   'num_of_sat_test_takers': '67',
#   'sat_critical_reading_avg_score': '342',
#   'sat_math_avg_score': '364',
#   'sat_writing_avg_score': '354'},
#  {'dbn': '32K554',
#   'school_name': 'ALL CITY LEADERSHIP SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '39',
#   'sat_critical_reading_avg_score': '428',
#   'sat_math_avg_score': '465',
#   'sat_writing_avg_score': '422'},
#  {'dbn': '32K556',
#   'school_name': 'BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCELLENCE',
#   'num_of_sat_test_takers': '23',
#   'sat_critical_reading_avg_score': '347',
#   'sat_math_avg_score': '358',
#   'sat_writing_avg_score': '350'},
#  {'dbn': '32K564',
#   'school_name': 'BUSHWICK COMMUNITY HIGH SCHOOL',
#   'num_of_sat_test_takers': '24',
#   'sat_critical_reading_avg_score': '359',
#   'sat_math_avg_score': '317',
#   'sat_writing_avg_score': '358'},
#  {'dbn': '75K371',
#   'school_name': 'P.S. 371 s LILLIAN L. RASHKIS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75M035',
#   'school_name': 'P.S. 035',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75Q256',
#   'school_name': 'P.S. Q256',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75Q811',
#   'school_name': 'P.S. Q811',
#   'num_of_sat_test_takers': '32',
#   'sat_critical_reading_avg_score': '429',
#   'sat_math_avg_score': '444',
#   'sat_writing_avg_score': '433'},
#  {'dbn': '75R025',
#   'school_name': 'SOUTH RICHMOND HIGH SCHOOL I.S./P.S. 25',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75X012',
#   'school_name': 'P.S. X012 LEWIS AND CLARK SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75X754',
#   'school_name': 'J. M. RAPPORT SCHOOL CAREER DEVELOPMENT',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '79M645',
#   'school_name': 'SCHOOL FOR COOPERATIVE TECHNICAL EDUCATION',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '79Q950',
#   'school_name': 'GED PLUS s CITYWIDE',
#   'num_of_sat_test_takers': '8',
#   'sat_critical_reading_avg_score': '496',
#   'sat_math_avg_score': '400',
#   'sat_writing_avg_score': '426'},
#  {'dbn': '79X490',
#   'school_name': 'PHOENIX ACADEMY',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '370',
#   'sat_writing_avg_score': '360'}]

# %%
import pandas as pd

# %%
df = pd.read_json(r.text)

# %%
df
# Out:
#         dbn                                    school_name  \
# 0    01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                     EAST SIDE COMMUNITY SCHOOL
# 3    01M458                      FORSYTH SATELLITE ACADEMY
# 4    01M509                        MARTA VALLE HIGH SCHOOL
# ..      ...                                            ...
# 473  75X012               P.S. X012 LEWIS AND CLARK SCHOOL
# 474  75X754        J. M. RAPPORT SCHOOL CAREER DEVELOPMENT
# 475  79M645     SCHOOL FOR COOPERATIVE TECHNICAL EDUCATION
# 476  79Q950                            GED PLUS s CITYWIDE
# 477  79X490                                PHOENIX ACADEMY
#
#     num_of_sat_test_takers sat_critical_reading_avg_score sat_math_avg_score  \
# 0                       29                            355                404
# 1                       91                            383                423
# 2                       70                            377                402
# 3                        7                            414                401
# 4                       44                            390                433
# ..                     ...                            ...                ...
# 473                      s                              s                  s
# 474                      s                              s                  s
# 475                      s                              s                  s
# 476                      8                            496                400
# 477                      9                            367                370
#
#     sat_writing_avg_score
# 0                     363
# 1                     366
# 2                     370
# 3                     359
# 4                     384
# ..                    ...
# 473                     s
# 474                     s
# 475                     s
# 476                   426
# 477                   360
#
# [478 rows x 6 columns]

# %%
payload = {'$limit':10,"$$app_token":"tq19sOJfOJFRot5OrORkOEbsS"}
r = requests.get('https://data.cityofnewyork.us/resource/f9bf-2cp4.json', params=payload)

# %%
r.text
# Out:
# '{\n  "code" : "permission_denied",\n  "error" : true,\n  "message" : "Invalid app_token specified"\n}\n'

# %%
r.json()
# Out:
# {'code': 'permission_denied',
#  'error': True,
#  'message': 'Invalid app_token specified'}

# %%
# form a get to grab the websites HTML
r = requests.get('https://basketball-reference.com/teams/PHI/2022.html')

# %%
from bs4 import BeautifulSoup

# %%
# turn the raw HTML into a soup object
soup = BeautifulSoup(r.text,'html.parser')

# %%
#One way of finding the table that contains the data
earnest_attempt = soup.findAll('div',attrs={'id':'div_roster'})

# %%
#Another way of finding the table that contains the data.
found_table = soup.findAll('table')

# %%
#I know the roster table is the first table that appears, so I'm grabbing it
roster_table = found_table[0]

# %%
#Grab all the table rows from the table.
player_rows = roster_table('tr')

# %%
player_rows
# Out:
# [<tr>
#  <th aria-label="No." class="poptip sort_default_asc center" data-stat="number" data-tip="Uniform Number" scope="col">No.</th>
#  <th aria-label="Player" class="poptip sort_default_asc center" data-stat="player" scope="col">Player</th>
#  <th aria-label="Pos" class="poptip sort_default_asc center" data-stat="pos" data-tip="Position" scope="col">Pos</th>
#  <th aria-label="Ht" class="poptip sort_default_asc center" data-stat="height" data-tip="Height" scope="col">Ht</th>
#  <th aria-label="Wt" class="poptip sort_default_asc center" data-stat="weight" data-tip="Weight" scope="col">Wt</th>
#  <th aria-label="Birth Date" class="poptip sort_default_asc center" data-stat="birth_date" scope="col">Birth Date</th>
#  <th aria-label=" " class="poptip center" data-stat="birth_country" scope="col"> </th>
#  <th aria-label="Exp" class="poptip sort_default_asc center" data-stat="years_experience" data-tip="Years experience in NBA/ABA (prior to this season)" scope="col">Exp</th>
#  <th aria-label="College" class="poptip sort_default_asc center" data-stat="college" scope="col">College</th>
#  </tr>,
#  <tr><th class="center" data-stat="number" scope="row">20</th><td class="left" csk="Niang,Georges" data-stat="player"><a href="/players/n/niangge01.html">Georges Niang</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">230</td><td class="left" csk="19930617" data-stat="birth_date">June 17, 1993</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="5" data-stat="years_experience">5</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=iowast">Iowa State</a></td></tr>,
#  <tr><th class="center iz" data-stat="number" scope="row">0</th><td class="left" csk="Maxey,Tyrese" data-stat="player"><a href="/players/m/maxeyty01.html">Tyrese Maxey</a></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="74.0" data-stat="height">6-2</td><td class="right" data-stat="weight">200</td><td class="left" csk="20001104" data-stat="birth_date">November 4, 2000</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=kentucky">Kentucky</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">12</th><td class="left" csk="Harris,Tobias" data-stat="player"><a href="/players/h/harrito02.html">Tobias Harris</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="80.0" data-stat="height">6-8</td><td class="right" data-stat="weight">226</td><td class="left" csk="19920715" data-stat="birth_date">July 15, 1992</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="10" data-stat="years_experience">10</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">30</th><td class="left" csk="Korkmaz,Furkan" data-stat="player"><a href="/players/k/korkmfu01.html">Furkan Korkmaz</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">202</td><td class="left" csk="19970724" data-stat="birth_date">July 24, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-tr" style="">tr</span></td><td class="right" csk="4" data-stat="years_experience">4</td><td class="left iz" data-stat="college"></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">21</th><td class="left" csk="Embiid,Joel" data-stat="player"><a href="/players/e/embiijo01.html">Joel Embiid</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="84.0" data-stat="height">7-0</td><td class="right" data-stat="weight">280</td><td class="left" csk="19940316" data-stat="birth_date">March 16, 1994</td><td class="right" data-stat="birth_country"><span class="f-i f-cm" style="">cm</span></td><td class="right" csk="5" data-stat="years_experience">5</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=kansas">Kansas</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">22</th><td class="left" csk="Thybulle,Matisse" data-stat="player"><a href="/players/t/thybuma01.html">Matisse Thybulle</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">201</td><td class="left" csk="19970304" data-stat="birth_date">March 4, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="2" data-stat="years_experience">2</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=washington">Washington</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">14</th><td class="left" csk="Green,Danny" data-stat="player"><a href="/players/g/greenda02.html">Danny Green</a></td><td class="center" csk="3" data-stat="pos">SF</td><td class="right" csk="78.0" data-stat="height">6-6</td><td class="right" data-stat="weight">215</td><td class="left" csk="19870622" data-stat="birth_date">June 22, 1987</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="12" data-stat="years_experience">12</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=unc">UNC</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">7</th><td class="left" csk="Joe,Isaiah" data-stat="player"><a href="/players/j/joeis01.html">Isaiah Joe</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="76.0" data-stat="height">6-4</td><td class="right" data-stat="weight">165</td><td class="left" csk="19990702" data-stat="birth_date">July 2, 1999</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=arkansas">Arkansas</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">18</th><td class="left" csk="Milton,Shake" data-stat="player"><a href="/players/m/miltosh01.html">Shake Milton</a></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">205</td><td class="left" csk="19960926" data-stat="birth_date">September 26, 1996</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="3" data-stat="years_experience">3</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=smethodist">SMU</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">44</th><td class="left" csk="Reed,Paul" data-stat="player"><a href="/players/r/reedpa01.html">Paul Reed</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="81.0" data-stat="height">6-9</td><td class="right" data-stat="weight">210</td><td class="left" csk="19990614" data-stat="birth_date">June 14, 1999</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=depaul">DePaul</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">23</th><td class="left" csk="Bassey,Charles" data-stat="player"><a href="/players/b/bassech01.html">Charles Bassey</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="83.0" data-stat="height">6-11</td><td class="right" data-stat="weight">235</td><td class="left" csk="20001028" data-stat="birth_date">October 28, 2000</td><td class="right" data-stat="birth_country"><span class="f-i f-ng" style="">ng</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=wkentucky">Western Kentucky</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">16</th><td class="left" csk="Brown,Charlie" data-stat="player"><a href="/players/b/brownch02.html">Charlie Brown Jr.</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="78.0" data-stat="height">6-6</td><td class="right" data-stat="weight">199</td><td class="left" csk="19970202" data-stat="birth_date">February 2, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="2" data-stat="years_experience">2</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=stjosephs">Saint Joseph's</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">1</th><td class="left" csk="Harden,James" data-stat="player"><a href="/players/h/hardeja01.html">James Harden</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">220</td><td class="left" csk="19890826" data-stat="birth_date">August 26, 1989</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="12" data-stat="years_experience">12</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=arizonast">Arizona State</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">5</th><td class="left" csk="Powell,Myles" data-stat="player"><a href="/players/p/powelmy01.html">Myles Powell</a>  <span class="note"><small>(TW)</small></span></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="74.0" data-stat="height">6-2</td><td class="right" data-stat="weight">195</td><td class="left" csk="19970707" data-stat="birth_date">July 7, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=setonhall">Seton Hall</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">9</th><td class="left" csk="Jordan,DeAndre" data-stat="player"><a href="/players/j/jordade01.html">DeAndre Jordan</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="83.0" data-stat="height">6-11</td><td class="right" data-stat="weight">265</td><td class="left" csk="19880721" data-stat="birth_date">July 21, 1988</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="13" data-stat="years_experience">13</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=texasam">Texas A&amp;M</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">8</th><td class="left" csk="Millsap,Paul" data-stat="player"><a href="/players/m/millspa01.html">Paul Millsap</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">257</td><td class="left" csk="19850210" data-stat="birth_date">February 10, 1985</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="15" data-stat="years_experience">15</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=latech">Louisiana Tech</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">11</th><td class="left" csk="Springer,Jaden" data-stat="player"><a href="/players/s/sprinja01.html">Jaden Springer</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="76.0" data-stat="height">6-4</td><td class="right" data-stat="weight">204</td><td class="left" csk="20020925" data-stat="birth_date">September 25, 2002</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>]

# %%
#I know that I don't need the first row, so I'm deleting it
del player_rows[0]

# %%
player_rows
# Out:
# [<tr><th class="center" data-stat="number" scope="row">20</th><td class="left" csk="Niang,Georges" data-stat="player"><a href="/players/n/niangge01.html">Georges Niang</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">230</td><td class="left" csk="19930617" data-stat="birth_date">June 17, 1993</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="5" data-stat="years_experience">5</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=iowast">Iowa State</a></td></tr>,
#  <tr><th class="center iz" data-stat="number" scope="row">0</th><td class="left" csk="Maxey,Tyrese" data-stat="player"><a href="/players/m/maxeyty01.html">Tyrese Maxey</a></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="74.0" data-stat="height">6-2</td><td class="right" data-stat="weight">200</td><td class="left" csk="20001104" data-stat="birth_date">November 4, 2000</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=kentucky">Kentucky</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">12</th><td class="left" csk="Harris,Tobias" data-stat="player"><a href="/players/h/harrito02.html">Tobias Harris</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="80.0" data-stat="height">6-8</td><td class="right" data-stat="weight">226</td><td class="left" csk="19920715" data-stat="birth_date">July 15, 1992</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="10" data-stat="years_experience">10</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">30</th><td class="left" csk="Korkmaz,Furkan" data-stat="player"><a href="/players/k/korkmfu01.html">Furkan Korkmaz</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">202</td><td class="left" csk="19970724" data-stat="birth_date">July 24, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-tr" style="">tr</span></td><td class="right" csk="4" data-stat="years_experience">4</td><td class="left iz" data-stat="college"></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">21</th><td class="left" csk="Embiid,Joel" data-stat="player"><a href="/players/e/embiijo01.html">Joel Embiid</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="84.0" data-stat="height">7-0</td><td class="right" data-stat="weight">280</td><td class="left" csk="19940316" data-stat="birth_date">March 16, 1994</td><td class="right" data-stat="birth_country"><span class="f-i f-cm" style="">cm</span></td><td class="right" csk="5" data-stat="years_experience">5</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=kansas">Kansas</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">22</th><td class="left" csk="Thybulle,Matisse" data-stat="player"><a href="/players/t/thybuma01.html">Matisse Thybulle</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">201</td><td class="left" csk="19970304" data-stat="birth_date">March 4, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="2" data-stat="years_experience">2</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=washington">Washington</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">14</th><td class="left" csk="Green,Danny" data-stat="player"><a href="/players/g/greenda02.html">Danny Green</a></td><td class="center" csk="3" data-stat="pos">SF</td><td class="right" csk="78.0" data-stat="height">6-6</td><td class="right" data-stat="weight">215</td><td class="left" csk="19870622" data-stat="birth_date">June 22, 1987</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="12" data-stat="years_experience">12</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=unc">UNC</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">7</th><td class="left" csk="Joe,Isaiah" data-stat="player"><a href="/players/j/joeis01.html">Isaiah Joe</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="76.0" data-stat="height">6-4</td><td class="right" data-stat="weight">165</td><td class="left" csk="19990702" data-stat="birth_date">July 2, 1999</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=arkansas">Arkansas</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">18</th><td class="left" csk="Milton,Shake" data-stat="player"><a href="/players/m/miltosh01.html">Shake Milton</a></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">205</td><td class="left" csk="19960926" data-stat="birth_date">September 26, 1996</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="3" data-stat="years_experience">3</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=smethodist">SMU</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">44</th><td class="left" csk="Reed,Paul" data-stat="player"><a href="/players/r/reedpa01.html">Paul Reed</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="81.0" data-stat="height">6-9</td><td class="right" data-stat="weight">210</td><td class="left" csk="19990614" data-stat="birth_date">June 14, 1999</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=depaul">DePaul</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">23</th><td class="left" csk="Bassey,Charles" data-stat="player"><a href="/players/b/bassech01.html">Charles Bassey</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="83.0" data-stat="height">6-11</td><td class="right" data-stat="weight">235</td><td class="left" csk="20001028" data-stat="birth_date">October 28, 2000</td><td class="right" data-stat="birth_country"><span class="f-i f-ng" style="">ng</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=wkentucky">Western Kentucky</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">16</th><td class="left" csk="Brown,Charlie" data-stat="player"><a href="/players/b/brownch02.html">Charlie Brown Jr.</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="78.0" data-stat="height">6-6</td><td class="right" data-stat="weight">199</td><td class="left" csk="19970202" data-stat="birth_date">February 2, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="2" data-stat="years_experience">2</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=stjosephs">Saint Joseph's</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">1</th><td class="left" csk="Harden,James" data-stat="player"><a href="/players/h/hardeja01.html">James Harden</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">220</td><td class="left" csk="19890826" data-stat="birth_date">August 26, 1989</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="12" data-stat="years_experience">12</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=arizonast">Arizona State</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">5</th><td class="left" csk="Powell,Myles" data-stat="player"><a href="/players/p/powelmy01.html">Myles Powell</a>  <span class="note"><small>(TW)</small></span></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="74.0" data-stat="height">6-2</td><td class="right" data-stat="weight">195</td><td class="left" csk="19970707" data-stat="birth_date">July 7, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=setonhall">Seton Hall</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">9</th><td class="left" csk="Jordan,DeAndre" data-stat="player"><a href="/players/j/jordade01.html">DeAndre Jordan</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="83.0" data-stat="height">6-11</td><td class="right" data-stat="weight">265</td><td class="left" csk="19880721" data-stat="birth_date">July 21, 1988</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="13" data-stat="years_experience">13</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=texasam">Texas A&amp;M</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">8</th><td class="left" csk="Millsap,Paul" data-stat="player"><a href="/players/m/millspa01.html">Paul Millsap</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">257</td><td class="left" csk="19850210" data-stat="birth_date">February 10, 1985</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="15" data-stat="years_experience">15</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=latech">Louisiana Tech</a></td></tr>,
#  <tr><th class="center" data-stat="number" scope="row">11</th><td class="left" csk="Springer,Jaden" data-stat="player"><a href="/players/s/sprinja01.html">Jaden Springer</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="76.0" data-stat="height">6-4</td><td class="right" data-stat="weight">204</td><td class="left" csk="20020925" data-stat="birth_date">September 25, 2002</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>]

# %%
#I am selecting all the Table Data from the first row
player_rows[0].find_all('td')
# Out:
# [<td class="left" csk="Niang,Georges" data-stat="player"><a href="/players/n/niangge01.html">Georges Niang</a></td>,
#  <td class="center" csk="4" data-stat="pos">PF</td>,
#  <td class="right" csk="79.0" data-stat="height">6-7</td>,
#  <td class="right" data-stat="weight">230</td>,
#  <td class="left" csk="19930617" data-stat="birth_date">June 17, 1993</td>,
#  <td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td>,
#  <td class="right" csk="5" data-stat="years_experience">5</td>,
#  <td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=iowast">Iowa State</a></td>]

# %%
#List comprehension to extract all the text data from each TD element.
extracted_text = [ele.text for ele in player_rows[0].find_all('td') ]

# %%
extracted_text
# Out:
# ['Georges Niang', 'PF', '6-7', '230', 'June 17, 1993', 'us', '5', 'Iowa State']

# %%
#This is going to serve as the keys in my k,v pairings
keys = ['Player_Name','Position','Height','Weight','DOB','COB','Experience','Alma_Matter']

# %%
#initialize a dict to hold the result of my for loop
player_dict = []


#Iterate over the list of rows in my table
#apply the same logic as before.
#Locate all the td elements
#extract all the text from the td elements
#zip them with my keys
for player in player_rows:
    found_rows = player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_dict.append(dict(zip(keys,stripped_text)))

# %%
player_dict
# Out:
# [{'Player_Name': 'Georges Niang',
#   'Position': 'PF',
#   'Height': '6-7',
#   'Weight': '230',
#   'DOB': 'June 17, 1993',
#   'COB': 'us',
#   'Experience': '5',
#   'Alma_Matter': 'Iowa State'},
#  {'Player_Name': 'Tyrese Maxey',
#   'Position': 'PG',
#   'Height': '6-2',
#   'Weight': '200',
#   'DOB': 'November 4, 2000',
#   'COB': 'us',
#   'Experience': '1',
#   'Alma_Matter': 'Kentucky'},
#  {'Player_Name': 'Tobias Harris',
#   'Position': 'PF',
#   'Height': '6-8',
#   'Weight': '226',
#   'DOB': 'July 15, 1992',
#   'COB': 'us',
#   'Experience': '10',
#   'Alma_Matter': 'Tennessee'},
#  {'Player_Name': 'Furkan Korkmaz',
#   'Position': 'SG',
#   'Height': '6-7',
#   'Weight': '202',
#   'DOB': 'July 24, 1997',
#   'COB': 'tr',
#   'Experience': '4',
#   'Alma_Matter': ''},
#  {'Player_Name': 'Joel Embiid',
#   'Position': 'C',
#   'Height': '7-0',
#   'Weight': '280',
#   'DOB': 'March 16, 1994',
#   'COB': 'cm',
#   'Experience': '5',
#   'Alma_Matter': 'Kansas'},
#  {'Player_Name': 'Matisse Thybulle',
#   'Position': 'SG',
#   'Height': '6-5',
#   'Weight': '201',
#   'DOB': 'March 4, 1997',
#   'COB': 'us',
#   'Experience': '2',
#   'Alma_Matter': 'Washington'},
#  {'Player_Name': 'Danny Green',
#   'Position': 'SF',
#   'Height': '6-6',
#   'Weight': '215',
#   'DOB': 'June 22, 1987',
#   'COB': 'us',
#   'Experience': '12',
#   'Alma_Matter': 'UNC'},
#  {'Player_Name': 'Isaiah Joe',
#   'Position': 'SG',
#   'Height': '6-4',
#   'Weight': '165',
#   'DOB': 'July 2, 1999',
#   'COB': 'us',
#   'Experience': '1',
#   'Alma_Matter': 'Arkansas'},
#  {'Player_Name': 'Shake Milton',
#   'Position': 'PG',
#   'Height': '6-5',
#   'Weight': '205',
#   'DOB': 'September 26, 1996',
#   'COB': 'us',
#   'Experience': '3',
#   'Alma_Matter': 'SMU'},
#  {'Player_Name': 'Paul Reed',
#   'Position': 'C',
#   'Height': '6-9',
#   'Weight': '210',
#   'DOB': 'June 14, 1999',
#   'COB': 'us',
#   'Experience': '1',
#   'Alma_Matter': 'DePaul'},
#  {'Player_Name': 'Charles Bassey',
#   'Position': 'PF',
#   'Height': '6-11',
#   'Weight': '235',
#   'DOB': 'October 28, 2000',
#   'COB': 'ng',
#   'Experience': 'R',
#   'Alma_Matter': 'Western Kentucky'},
#  {'Player_Name': 'Charlie Brown Jr.',
#   'Position': 'SG',
#   'Height': '6-6',
#   'Weight': '199',
#   'DOB': 'February 2, 1997',
#   'COB': 'us',
#   'Experience': '2',
#   'Alma_Matter': "Saint Joseph's"},
#  {'Player_Name': 'James Harden',
#   'Position': 'SG',
#   'Height': '6-5',
#   'Weight': '220',
#   'DOB': 'August 26, 1989',
#   'COB': 'us',
#   'Experience': '12',
#   'Alma_Matter': 'Arizona State'},
#  {'Player_Name': 'Myles Powell\xa0\xa0(TW)',
#   'Position': 'PG',
#   'Height': '6-2',
#   'Weight': '195',
#   'DOB': 'July 7, 1997',
#   'COB': 'us',
#   'Experience': 'R',
#   'Alma_Matter': 'Seton Hall'},
#  {'Player_Name': 'DeAndre Jordan',
#   'Position': 'C',
#   'Height': '6-11',
#   'Weight': '265',
#   'DOB': 'July 21, 1988',
#   'COB': 'us',
#   'Experience': '13',
#   'Alma_Matter': 'Texas A&M'},
#  {'Player_Name': 'Paul Millsap',
#   'Position': 'PF',
#   'Height': '6-7',
#   'Weight': '257',
#   'DOB': 'February 10, 1985',
#   'COB': 'us',
#   'Experience': '15',
#   'Alma_Matter': 'Louisiana Tech'},
#  {'Player_Name': 'Jaden Springer',
#   'Position': 'SG',
#   'Height': '6-4',
#   'Weight': '204',
#   'DOB': 'September 25, 2002',
#   'COB': 'us',
#   'Experience': 'R',
#   'Alma_Matter': 'Tennessee'}]

# %%
#create a new df from my list of Dicts
df = pd.DataFrame(player_dict)

# %%
df
# Out:
#            Player_Name Position Height Weight                 DOB COB  \
# 0        Georges Niang       PF    6-7    230       June 17, 1993  us
# 1         Tyrese Maxey       PG    6-2    200    November 4, 2000  us
# 2        Tobias Harris       PF    6-8    226       July 15, 1992  us
# 3       Furkan Korkmaz       SG    6-7    202       July 24, 1997  tr
# 4          Joel Embiid        C    7-0    280      March 16, 1994  cm
# 5     Matisse Thybulle       SG    6-5    201       March 4, 1997  us
# 6          Danny Green       SF    6-6    215       June 22, 1987  us
# 7           Isaiah Joe       SG    6-4    165        July 2, 1999  us
# 8         Shake Milton       PG    6-5    205  September 26, 1996  us
# 9            Paul Reed        C    6-9    210       June 14, 1999  us
# 10      Charles Bassey       PF   6-11    235    October 28, 2000  ng
# 11   Charlie Brown Jr.       SG    6-6    199    February 2, 1997  us
# 12        James Harden       SG    6-5    220     August 26, 1989  us
# 13  Myles Powell  (TW)       PG    6-2    195        July 7, 1997  us
# 14      DeAndre Jordan        C   6-11    265       July 21, 1988  us
# 15        Paul Millsap       PF    6-7    257   February 10, 1985  us
# 16      Jaden Springer       SG    6-4    204  September 25, 2002  us
#
#    Experience       Alma_Matter
# 0           5        Iowa State
# 1           1          Kentucky
# 2          10         Tennessee
# 3           4
# 4           5            Kansas
# 5           2        Washington
# 6          12               UNC
# 7           1          Arkansas
# 8           3               SMU
# 9           1            DePaul
# 10          R  Western Kentucky
# 11          2    Saint Joseph's
# 12         12     Arizona State
# 13          R        Seton Hall
# 14         13         Texas A&M
# 15         15    Louisiana Tech
# 16          R         Tennessee

# %%
#Method number 2 using lists
player_dict = []
for player in player_rows:
    found_rows = player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_dict.append(stripped_text)

# %%
#Initialize my DF using list of lists
df = pd.DataFrame(player_dict,columns=['Player_Name','Position','Height','Weight','DOB','COB','Experience','Alma_Matter'])

# %%
df
# Out:
#            Player_Name Position Height Weight                 DOB COB  \
# 0        Georges Niang       PF    6-7    230       June 17, 1993  us
# 1         Tyrese Maxey       PG    6-2    200    November 4, 2000  us
# 2        Tobias Harris       PF    6-8    226       July 15, 1992  us
# 3       Furkan Korkmaz       SG    6-7    202       July 24, 1997  tr
# 4          Joel Embiid        C    7-0    280      March 16, 1994  cm
# 5     Matisse Thybulle       SG    6-5    201       March 4, 1997  us
# 6          Danny Green       SF    6-6    215       June 22, 1987  us
# 7           Isaiah Joe       SG    6-4    165        July 2, 1999  us
# 8         Shake Milton       PG    6-5    205  September 26, 1996  us
# 9            Paul Reed        C    6-9    210       June 14, 1999  us
# 10      Charles Bassey       PF   6-11    235    October 28, 2000  ng
# 11   Charlie Brown Jr.       SG    6-6    199    February 2, 1997  us
# 12        James Harden       SG    6-5    220     August 26, 1989  us
# 13  Myles Powell  (TW)       PG    6-2    195        July 7, 1997  us
# 14      DeAndre Jordan        C   6-11    265       July 21, 1988  us
# 15        Paul Millsap       PF    6-7    257   February 10, 1985  us
# 16      Jaden Springer       SG    6-4    204  September 25, 2002  us
#
#    Experience       Alma_Matter
# 0           5        Iowa State
# 1           1          Kentucky
# 2          10         Tennessee
# 3           4
# 4           5            Kansas
# 5           2        Washington
# 6          12               UNC
# 7           1          Arkansas
# 8           3               SMU
# 9           1            DePaul
# 10          R  Western Kentucky
# 11          2    Saint Joseph's
# 12         12     Arizona State
# 13          R        Seton Hall
# 14         13         Texas A&M
# 15         15    Louisiana Tech
# 16          R         Tennessee

# %%
soup.findAll('table')
# Out:
# [<table class="sortable stats_table" data-cols-to-freeze=",2" id="roster">
#  <caption>Roster Table</caption>
#  <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
#  <thead>
#  <tr>
#  <th aria-label="No." class="poptip sort_default_asc center" data-stat="number" data-tip="Uniform Number" scope="col">No.</th>
#  <th aria-label="Player" class="poptip sort_default_asc center" data-stat="player" scope="col">Player</th>
#  <th aria-label="Pos" class="poptip sort_default_asc center" data-stat="pos" data-tip="Position" scope="col">Pos</th>
#  <th aria-label="Ht" class="poptip sort_default_asc center" data-stat="height" data-tip="Height" scope="col">Ht</th>
#  <th aria-label="Wt" class="poptip sort_default_asc center" data-stat="weight" data-tip="Weight" scope="col">Wt</th>
#  <th aria-label="Birth Date" class="poptip sort_default_asc center" data-stat="birth_date" scope="col">Birth Date</th>
#  <th aria-label=" " class="poptip center" data-stat="birth_country" scope="col"> </th>
#  <th aria-label="Exp" class="poptip sort_default_asc center" data-stat="years_experience" data-tip="Years experience in NBA/ABA (prior to this season)" scope="col">Exp</th>
#  <th aria-label="College" class="poptip sort_default_asc center" data-stat="college" scope="col">College</th>
#  </tr>
#  </thead>
#  <tbody><tr><th class="center" data-stat="number" scope="row">20</th><td class="left" csk="Niang,Georges" data-stat="player"><a href="/players/n/niangge01.html">Georges Niang</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">230</td><td class="left" csk="19930617" data-stat="birth_date">June 17, 1993</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="5" data-stat="years_experience">5</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=iowast">Iowa State</a></td></tr>
#  <tr><th class="center iz" data-stat="number" scope="row">0</th><td class="left" csk="Maxey,Tyrese" data-stat="player"><a href="/players/m/maxeyty01.html">Tyrese Maxey</a></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="74.0" data-stat="height">6-2</td><td class="right" data-stat="weight">200</td><td class="left" csk="20001104" data-stat="birth_date">November 4, 2000</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=kentucky">Kentucky</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">12</th><td class="left" csk="Harris,Tobias" data-stat="player"><a href="/players/h/harrito02.html">Tobias Harris</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="80.0" data-stat="height">6-8</td><td class="right" data-stat="weight">226</td><td class="left" csk="19920715" data-stat="birth_date">July 15, 1992</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="10" data-stat="years_experience">10</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">30</th><td class="left" csk="Korkmaz,Furkan" data-stat="player"><a href="/players/k/korkmfu01.html">Furkan Korkmaz</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">202</td><td class="left" csk="19970724" data-stat="birth_date">July 24, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-tr" style="">tr</span></td><td class="right" csk="4" data-stat="years_experience">4</td><td class="left iz" data-stat="college"></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">21</th><td class="left" csk="Embiid,Joel" data-stat="player"><a href="/players/e/embiijo01.html">Joel Embiid</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="84.0" data-stat="height">7-0</td><td class="right" data-stat="weight">280</td><td class="left" csk="19940316" data-stat="birth_date">March 16, 1994</td><td class="right" data-stat="birth_country"><span class="f-i f-cm" style="">cm</span></td><td class="right" csk="5" data-stat="years_experience">5</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=kansas">Kansas</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">22</th><td class="left" csk="Thybulle,Matisse" data-stat="player"><a href="/players/t/thybuma01.html">Matisse Thybulle</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">201</td><td class="left" csk="19970304" data-stat="birth_date">March 4, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="2" data-stat="years_experience">2</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=washington">Washington</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">14</th><td class="left" csk="Green,Danny" data-stat="player"><a href="/players/g/greenda02.html">Danny Green</a></td><td class="center" csk="3" data-stat="pos">SF</td><td class="right" csk="78.0" data-stat="height">6-6</td><td class="right" data-stat="weight">215</td><td class="left" csk="19870622" data-stat="birth_date">June 22, 1987</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="12" data-stat="years_experience">12</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=unc">UNC</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">7</th><td class="left" csk="Joe,Isaiah" data-stat="player"><a href="/players/j/joeis01.html">Isaiah Joe</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="76.0" data-stat="height">6-4</td><td class="right" data-stat="weight">165</td><td class="left" csk="19990702" data-stat="birth_date">July 2, 1999</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=arkansas">Arkansas</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">18</th><td class="left" csk="Milton,Shake" data-stat="player"><a href="/players/m/miltosh01.html">Shake Milton</a></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">205</td><td class="left" csk="19960926" data-stat="birth_date">September 26, 1996</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="3" data-stat="years_experience">3</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=smethodist">SMU</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">44</th><td class="left" csk="Reed,Paul" data-stat="player"><a href="/players/r/reedpa01.html">Paul Reed</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="81.0" data-stat="height">6-9</td><td class="right" data-stat="weight">210</td><td class="left" csk="19990614" data-stat="birth_date">June 14, 1999</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=depaul">DePaul</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">23</th><td class="left" csk="Bassey,Charles" data-stat="player"><a href="/players/b/bassech01.html">Charles Bassey</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="83.0" data-stat="height">6-11</td><td class="right" data-stat="weight">235</td><td class="left" csk="20001028" data-stat="birth_date">October 28, 2000</td><td class="right" data-stat="birth_country"><span class="f-i f-ng" style="">ng</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=wkentucky">Western Kentucky</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">16</th><td class="left" csk="Brown,Charlie" data-stat="player"><a href="/players/b/brownch02.html">Charlie Brown Jr.</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="78.0" data-stat="height">6-6</td><td class="right" data-stat="weight">199</td><td class="left" csk="19970202" data-stat="birth_date">February 2, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="2" data-stat="years_experience">2</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=stjosephs">Saint Joseph's</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">1</th><td class="left" csk="Harden,James" data-stat="player"><a href="/players/h/hardeja01.html">James Harden</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">220</td><td class="left" csk="19890826" data-stat="birth_date">August 26, 1989</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="12" data-stat="years_experience">12</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=arizonast">Arizona State</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">5</th><td class="left" csk="Powell,Myles" data-stat="player"><a href="/players/p/powelmy01.html">Myles Powell</a>  <span class="note"><small>(TW)</small></span></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="74.0" data-stat="height">6-2</td><td class="right" data-stat="weight">195</td><td class="left" csk="19970707" data-stat="birth_date">July 7, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=setonhall">Seton Hall</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">9</th><td class="left" csk="Jordan,DeAndre" data-stat="player"><a href="/players/j/jordade01.html">DeAndre Jordan</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="83.0" data-stat="height">6-11</td><td class="right" data-stat="weight">265</td><td class="left" csk="19880721" data-stat="birth_date">July 21, 1988</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="13" data-stat="years_experience">13</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=texasam">Texas A&amp;M</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">8</th><td class="left" csk="Millsap,Paul" data-stat="player"><a href="/players/m/millspa01.html">Paul Millsap</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">257</td><td class="left" csk="19850210" data-stat="birth_date">February 10, 1985</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="15" data-stat="years_experience">15</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=latech">Louisiana Tech</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">11</th><td class="left" csk="Springer,Jaden" data-stat="player"><a href="/players/s/sprinja01.html">Jaden Springer</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="76.0" data-stat="height">6-4</td><td class="right" data-stat="weight">204</td><td class="left" csk="20020925" data-stat="birth_date">September 25, 2002</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>
#  </tbody></table>,
#  <table class="stats_table sortable" data-cols-to-freeze=",2" id="per_game"> <caption>Per Game Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rk" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th> <th aria-label=" " class="poptip sort_default_asc center" data-stat="player" scope="col"> </th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Player's age on February 1 of the season" scope="col">Age</th> <th aria-label="Games" class="poptip center" data-stat="g" data-tip="Games" scope="col">G</th> <th aria-label="Games Started" class="poptip center" data-stat="gs" data-tip="Games Started" scope="col">GS</th> <th aria-label="Minutes Played Per Game" class="poptip center" data-stat="mp_per_g" data-tip="Minutes Played Per Game" scope="col">MP</th> <th aria-label="Field Goals Per Game" class="poptip center" data-stat="fg_per_g" data-tip="Field Goals Per Game" scope="col">FG</th> <th aria-label="Field Goal Attempts Per Game" class="poptip center" data-stat="fga_per_g" data-tip="Field Goal Attempts Per Game" scope="col">FGA</th> <th aria-label="Field Goal Percentage" class="poptip center" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">FG%</th> <th aria-label="3-Point Field Goals Per Game" class="poptip center" data-stat="fg3_per_g" data-tip="3-Point Field Goals Per Game" scope="col">3P</th> <th aria-label="3-Point Field Goal Attempts Per Game" class="poptip center" data-stat="fg3a_per_g" data-tip="3-Point Field Goal Attempts Per Game" scope="col">3PA</th> <th aria-label="3-Point Field Goal Percentage" class="poptip center" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage" scope="col">3P%</th> <th aria-label="2-Point Field Goals Per Game" class="poptip center" data-stat="fg2_per_g" data-tip="2-Point Field Goals Per Game" scope="col">2P</th> <th aria-label="2-Point Field Goal Attempts Per Game" class="poptip center" data-stat="fg2a_per_g" data-tip="2-Point Field Goal Attempts Per Game" scope="col">2PA</th> <th aria-label="2-Point Field Goal Percentage" class="poptip center" data-stat="fg2_pct" data-tip="2-Point Field Goal Percentage" scope="col">2P%</th> <th aria-label="Effective Field Goal Percentage" class="poptip center" data-stat="efg_pct" data-tip="&lt;strong&gt;Effective Field Goal Percentage&lt;/strong&gt;&lt;br&gt;This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal." scope="col">eFG%</th> <th aria-label="Free Throws Per Game" class="poptip center" data-stat="ft_per_g" data-tip="Free Throws Per Game" scope="col">FT</th> <th aria-label="Free Throw Attempts Per Game" class="poptip center" data-stat="fta_per_g" data-tip="Free Throw Attempts Per Game" scope="col">FTA</th> <th aria-label="Free Throw Percentage" class="poptip center" data-stat="ft_pct" data-tip="Free Throw Percentage" scope="col">FT%</th> <th aria-label="Offensive Rebounds Per Game" class="poptip center" data-stat="orb_per_g" data-tip="Offensive Rebounds Per Game" scope="col">ORB</th> <th aria-label="Defensive Rebounds Per Game" class="poptip center" data-stat="drb_per_g" data-tip="Defensive Rebounds Per Game" scope="col">DRB</th> <th aria-label="Total Rebounds Per Game" class="poptip center" data-stat="trb_per_g" data-tip="Total Rebounds Per Game" scope="col">TRB</th> <th aria-label="Assists Per Game" class="poptip center" data-stat="ast_per_g" data-tip="Assists Per Game" scope="col">AST</th> <th aria-label="Steals Per Game" class="poptip center" data-stat="stl_per_g" data-tip="Steals Per Game" scope="col">STL</th> <th aria-label="Blocks Per Game" class="poptip center" data-stat="blk_per_g" data-tip="Blocks Per Game" scope="col">BLK</th> <th aria-label="Turnovers Per Game" class="poptip  ...
#  <table class="stats_table sortable" data-cols-to-freeze=",2" id="totals"> <caption>Totals Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rk" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th> <th aria-label=" " class="poptip sort_default_asc center" data-stat="player" scope="col"> </th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Player's age on February 1 of the season" scope="col">Age</th> <th aria-label="Games" class="poptip center" data-stat="g" data-tip="Games" scope="col">G</th> <th aria-label="Games Started" class="poptip center" data-stat="gs" data-tip="Games Started" scope="col">GS</th> <th aria-label="Minutes Played" class="poptip center" data-stat="mp" data-tip="Minutes Played" scope="col">MP</th> <th aria-label="Field Goals" class="poptip center" data-stat="fg" data-tip="Field Goals" scope="col">FG</th> <th aria-label="FGA" class="poptip center" data-stat="fga" data-tip="Field Goal Attempts" scope="col">FGA</th> <th aria-label="Field Goal Percentage" class="poptip center" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">FG%</th> <th aria-label="3-Point Field Goals" class="poptip center" data-stat="fg3" data-tip="3-Point Field Goals" scope="col">3P</th> <th aria-label="3-Point Field Goal Attempts" class="poptip center" data-stat="fg3a" data-tip="3-Point Field Goal Attempts" scope="col">3PA</th> <th aria-label="3-Point Field Goal Percentage" class="poptip center" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage" scope="col">3P%</th> <th aria-label="2-Point Field Goals" class="poptip center" data-stat="fg2" data-tip="2-Point Field Goals" scope="col">2P</th> <th aria-label="2-point Field Goal Attempts" class="poptip center" data-stat="fg2a" data-tip="2-point Field Goal Attempts" scope="col">2PA</th> <th aria-label="2-Point Field Goal Percentage" class="poptip center" data-stat="fg2_pct" data-tip="2-Point Field Goal Percentage" scope="col">2P%</th> <th aria-label="Effective Field Goal Percentage" class="poptip center" data-stat="efg_pct" data-tip="&lt;strong&gt;Effective Field Goal Percentage&lt;/strong&gt;&lt;br&gt;This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal." scope="col">eFG%</th> <th aria-label="Free Throws" class="poptip center" data-stat="ft" data-tip="Free Throws" scope="col">FT</th> <th aria-label="Free Throw Attempts" class="poptip center" data-stat="fta" data-tip="Free Throw Attempts" scope="col">FTA</th> <th aria-label="Free Throw Percentage" class="poptip center" data-stat="ft_pct" data-tip="Free Throw Percentage" scope="col">FT%</th> <th aria-label="Offensive Rebounds" class="poptip center" data-stat="orb" data-tip="Offensive Rebounds" scope="col">ORB</th> <th aria-label="Defensive Rebounds" class="poptip center" data-stat="drb" data-tip="Defensive Rebounds" scope="col">DRB</th> <th aria-label="Total Rebounds" class="poptip center" data-stat="trb" data-tip="Total Rebounds" scope="col">TRB</th> <th aria-label="Assists" class="poptip center" data-stat="ast" data-tip="Assists" scope="col">AST</th> <th aria-label="Steals" class="poptip center" data-stat="stl" data-tip="Steals" scope="col">STL</th> <th aria-label="Blocks" class="poptip center" data-stat="blk" data-tip="Blocks" scope="col">BLK</th> <th aria-label="Turnovers" class="poptip center" data-stat="tov" data-tip="Turnovers" scope="col">TOV</th> <th aria-label="Personal Fouls" class="poptip center" data-stat="pf" data-tip="Personal Fouls" scope="col">PF</th> <th aria-label="Points" class="poptip center" data-stat="pts" data-tip="Points" scope="col">PTS</th> </tr> </thead> <tbody> <tr><th class="center" data-stat="ranker" scope="row">1</th><td class="left" csk="Ma ...
#  <table class="stats_table sortable" data-cols-to-freeze=",2" id="advanced"> <caption>Advanced Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rk" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th> <th aria-label=" " class="poptip sort_default_asc center" data-stat="player" scope="col"> </th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Player's age on February 1 of the season" scope="col">Age</th> <th aria-label="Games" class="poptip center" data-stat="g" data-tip="Games" scope="col">G</th> <th aria-label="Minutes Played" class="poptip center" data-stat="mp" data-tip="Minutes Played" scope="col">MP</th> <th aria-label="Player Efficiency Rating" class="poptip center" data-stat="per" data-tip="&lt;b&gt;Player Efficiency Rating&lt;/b&gt;&lt;br&gt;A measure of per-minute production standardized such that the league average is 15." scope="col">PER</th> <th aria-label="True Shooting Percentage" class="poptip center" data-stat="ts_pct" data-tip="&lt;strong&gt;True Shooting Percentage&lt;/strong&gt;&lt;br&gt;A measure of shooting efficiency that takes into account 2-point field goals, 3-point field goals, and free throws." scope="col">TS%</th> <th aria-label="3-Point Attempt Rate" class="poptip center" data-stat="fg3a_per_fga_pct" data-tip="&lt;strong&gt;3-Point Attempt Rate&lt;/strong&gt;&lt;br&gt;Percentage of FG Attempts from 3-Point Range" scope="col">3PAr</th> <th aria-label="Free Throw Attempt Rate" class="poptip center" data-stat="fta_per_fga_pct" data-tip="&lt;strong&gt;Free Throw Attempt Rate&lt;/strong&gt;&lt;br&gt;Number of FT Attempts Per FG Attempt" scope="col">FTr</th> <th aria-label="Offensive Rebound Percentage" class="poptip center" data-stat="orb_pct" data-tip="&lt;b&gt;Offensive Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available offensive rebounds a player grabbed while they were on the floor." scope="col">ORB%</th> <th aria-label="Defensive Rebound Percentage" class="poptip center" data-stat="drb_pct" data-tip="&lt;b&gt;Defensive Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available defensive rebounds a player grabbed while they were on the floor." scope="col">DRB%</th> <th aria-label="Total Rebound Percentage" class="poptip center" data-stat="trb_pct" data-tip="&lt;b&gt;Total Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available rebounds a player grabbed while they were on the floor." scope="col">TRB%</th> <th aria-label="Assist Percentage" class="poptip center" data-stat="ast_pct" data-tip="&lt;b&gt;Assist Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of teammate field goals a player assisted while they were on the floor." scope="col">AST%</th> <th aria-label="Steal Percentage" class="poptip center" data-stat="stl_pct" data-tip="&lt;b&gt;Steal Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of opponent possessions that end with a steal by the player while they were on the floor." scope="col">STL%</th> <th aria-label="Block Percentage" class="poptip center" data-stat="blk_pct" data-tip="&lt;b&gt;Block Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of opponent two-point field goal attempts blocked by the player while they were on the floor." scope="col">BLK%</th> <th aria-label="Turnover Percentage" class="poptip sort_default_asc center" data-stat="tov_pct" data-tip="&lt;b&gt;Turnover Percentage&lt;/b&gt;&lt;br&gt;An estimate of turnovers committed per 100 plays." scope="col">TOV%</th> <th aria-label="Usage Percentage" class="poptip center" data-stat="usg_pct" data-tip="&lt;b&gt;Usage Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of team plays used by a player while they were on the floo ...

# %%
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
#driver = webdriver.Chrome(executable_path='C:/path/to/chromedriver.exe')

# %%
#Code to initialize the chrome driver
driver = webdriver.Chrome()

#have the chrome browser issue a get request to googl
driver.get("http://www.google.com")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\common\service.py:71, in Service.start(self)
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=69'>70</a>     cmd.extend(self.command_line_args())
# ---> <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=70'>71</a>     self.process = subprocess.Popen(cmd, env=self.env,
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=71'>72</a>                                     close_fds=system() != 'Windows',
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=72'>73</a>                                     stdout=self.log_file,
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=73'>74</a>                                     stderr=self.log_file,
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=74'>75</a>                                     stdin=PIPE,
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=75'>76</a>                                     creationflags=self.creationflags)
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=76'>77</a> except TypeError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0\lib\subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=962'>963</a>             self.stderr = io.TextIOWrapper(self.stderr,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=963'>964</a>                     encoding=encoding, errors=errors)
# --> <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=965'>966</a>     self._execute_child(args, executable, preexec_fn, close_fds,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=966'>967</a>                         pass_fds, cwd, env,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=967'>968</a>                         startupinfo, creationflags, shell,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=968'>969</a>                         p2cread, p2cwrite,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=969'>970</a>                         c2pread, c2pwrite,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=970'>971</a>                         errread, errwrite,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=971'>972</a>                         restore_signals,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=972'>973</a>                         gid, gids, uid, umask,
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=973'>974</a>                         start_new_session)
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=974'>975</a> except:
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=975'>976</a>     # Cleanup if the child failed starting.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0\lib\subprocess.py:1435, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1433'>1434</a> try:
# -> <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1434'>1435</a>     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1435'>1436</a>                              # no special security
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1436'>1437</a>                              None, None,
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1437'>1438</a>                              int(not close_fds),
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1438'>1439</a>                              creationflags,
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1439'>1440</a>                              env,
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1440'>1441</a>                              cwd,
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1441'>1442</a>                              startupinfo)
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1442'>1443</a> finally:
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1443'>1444</a>     # Child is launched. Close the parent's copy of those pipe
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1444'>1445</a>     # handles that only the child should have open.  You need
#    (...)
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1447'>1448</a>     # pipe will not close when the child process exits and the
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.10_3.10.1264.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1448'>1449</a>     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# c:\Users\daiya\VisualStudioProjects\DS2022\week-026\In_class_notes.ipynb Cell 49' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/daiya/VisualStudioProjects/DS2022/week-026/In_class_notes.ipynb#ch0000048?line=0'>1</a> #Code to initialize the chrome driver
# ----> <a href='vscode-notebook-cell:/c%3A/Users/daiya/VisualStudioProjects/DS2022/week-026/In_class_notes.ipynb#ch0000048?line=1'>2</a> driver = webdriver.Chrome()
#       <a href='vscode-notebook-cell:/c%3A/Users/daiya/VisualStudioProjects/DS2022/week-026/In_class_notes.ipynb#ch0000048?line=3'>4</a> #have the chrome browser issue a get request to googl
#       <a href='vscode-notebook-cell:/c%3A/Users/daiya/VisualStudioProjects/DS2022/week-026/In_class_notes.ipynb#ch0000048?line=4'>5</a> driver.get("http://www.google.com")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\chrome\webdriver.py:70, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chrome/webdriver.py?line=66'>67</a> if not service:
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chrome/webdriver.py?line=67'>68</a>     service = Service(executable_path, port, service_args, service_log_path)
# ---> <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chrome/webdriver.py?line=69'>70</a> super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chrome/webdriver.py?line=70'>71</a>                                 port, options,
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chrome/webdriver.py?line=71'>72</a>                                 service_args, desired_capabilities,
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chrome/webdriver.py?line=72'>73</a>                                 service_log_path, service, keep_alive)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\chromium\webdriver.py:90, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=86'>87</a>     raise AttributeError('service cannot be None')
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=88'>89</a> self.service = service
# ---> <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=89'>90</a> self.service.start()
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=91'>92</a> try:
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=92'>93</a>     RemoteWebDriver.__init__(
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=93'>94</a>         self,
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=94'>95</a>         command_executor=ChromiumRemoteConnection(
#    (...)
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=97'>98</a>             keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/chromium/webdriver.py?line=98'>99</a>         options=options)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\common\service.py:81, in Service.start(self)
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=78'>79</a> except OSError as err:
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=79'>80</a>     if err.errno == errno.ENOENT:
# ---> <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=80'>81</a>         raise WebDriverException(
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=81'>82</a>             "'%s' executable needs to be in PATH. %s" % (
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=82'>83</a>                 os.path.basename(self.path), self.start_error_message)
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=83'>84</a>         )
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=84'>85</a>     elif err.errno == errno.EACCES:
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=85'>86</a>         raise WebDriverException(
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=86'>87</a>             "'%s' executable may have wrong permissions. %s" % (
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=87'>88</a>                 os.path.basename(self.path), self.start_error_message)
#      <a href='file:///c%3A/Users/daiya/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/selenium/webdriver/common/service.py?line=88'>89</a>         )
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://chromedriver.chromium.org/home

# %%
search_box = driver.find_element(By.NAME, "q")

# %%
search_button = driver.find_element(By.NAME, "btnK")

# %%
search_box.send_keys("Selenium")

# %%
search_button.click()

# %%
driver.find_element(By.NAME, "q").get_attribute("value")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys



#driver = webdriver.Chrome(executable_path='C:/path/to/chromedriver.exe')
#This is for you want the driver in a static place

driver = webdriver.Chrome()
#Initialize the chrome instance

driver.get("http://www.google.com")
#Issue a get request to the website


search_box = driver.find_element(By.NAME, "q")
#Search the webpage for an element called a, set it equal to search_box


driver.implicitly_wait(2)
#Tell the driver to not do anything for 2 seconds ( Why? It's because we need the search button to load in after some text is being put into the search box)

search_button = driver.find_element(By.NAME, "btnK")
#Find the element on the webpage called btnL


search_box.send_keys("Selenium")
#Mimic the keystrokes S E L E N I U M to the search box


search_button.click()
#Mimic a click of the button on the search_button element



driver.find_element(By.NAME, "q").get_attribute("value") # => "Selenium"
#Find the element on the webpage called q, and get the attribute value.

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(2)



driver.get("https://www.basketball-reference.com/teams/PHI/2022.html")
roster_table = driver.find_element(By.ID, "roster")
raw_html = roster_table.get_attribute('innerHTML')
print(roster_table.get_attribute('innerHTML'))
driver.close()

# %%
soup = BeautifulSoup(raw_html,'html.parser')

# %%
all_rows = soup.findAll('tr')

# %%
del all_rows[0]

# %%
player_dict = []
player_list = []
keys = ['Player_Name','Position','Height','Weight','DOB','COB','Number','Alma_Matter']
for player in all_rows:
    found_rows= player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_dict.append(dict(zip(keys,stripped_text)))


player_dict

# %%
df = pd.DataFrame(player_dict)

# %%
df

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(2)



driver.get("https://www.basketball-reference.com/teams/PHI/2022.html")
salaries_table = driver.find_element(By.ID, "salaries2")
raw_html = salaries_table.get_attribute('innerHTML')
print(salaries_table.get_attribute('innerHTML'))
driver.close()

# %%
soup = BeautifulSoup(raw_html,'html.parser')

# %%
player_salaries = soup.findAll('tr')

# %%
del player_salaries[0]

# %%
player_salaries

# %%
player_salaries_list = []
for player in player_salaries:
    found_rows= player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_salaries_list.append(stripped_text)

# %%
player_salaries_list
