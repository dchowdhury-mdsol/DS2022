# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('Netflix subscription fee Dec-2021.csv')
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 0            ar       Argentina                4760             3154
# 1            au       Australia                6114             4050
# 2            at         Austria                5640             3779
# 3            be         Belgium                4990             3374
# 4            bo         Bolivia                4991             3155
# ..          ...             ...                 ...              ...
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ...

# %%
df.dtypes
# Out:
# Country_code                      object
# Country                           object
# Total Library Size                 int64
# No. of TV Shows                    int64
# No. of Movies                      int64
# Cost Per Month - Basic ($)       float64
# Cost Per Month - Standard ($)    float64
# Cost Per Month - Premium ($)     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country_code                   65 non-null     object
#  1   Country                        65 non-null     object
#  2   Total Library Size             65 non-null     int64
#  3   No. of TV Shows                65 non-null     int64
#  4   No. of Movies                  65 non-null     int64
#  5   Cost Per Month - Basic ($)     65 non-null     float64
#  6   Cost Per Month - Standard ($)  65 non-null     float64
#  7   Cost Per Month - Premium ($)   65 non-null     float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 4.2+ KB

# %%
df.describe()
# Out:
#        Total Library Size  No. of TV Shows  No. of Movies  \
# count           65.000000        65.000000      65.000000
# mean          5314.415385      3518.953846    1795.461538
# std            980.322633       723.010556     327.279748
# min           2274.000000      1675.000000     373.000000
# 25%           4948.000000      3154.000000    1628.000000
# 50%           5195.000000      3512.000000    1841.000000
# 75%           5952.000000      3832.000000    1980.000000
# max           7325.000000      5234.000000    2387.000000
#
#        Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# count                   65.000000                      65.000000
# mean                     8.368462                      11.990000
# std                      1.937819                       2.863979
# min                      1.970000                       3.000000
# 25%                      7.990000                      10.710000
# ...

# %%
df.memory_usage(deep=True)
# Out:
# Index                             128
# Country_code                     3835
# Country                          4209
# Total Library Size                520
# No. of TV Shows                   520
# No. of Movies                     520
# Cost Per Month - Basic ($)        520
# Cost Per Month - Standard ($)     520
# Cost Per Month - Premium ($)      520
# dtype: int64

# %%
top_10, bottom_10, random_10 = df.sort_values(by=['Total Library Size'], ascending=False), df.sort_values(by=['Total Library Size'], ascending=True), df.sample(10)
top_10, bottom_10 = top_10.nlargest(10, ['Total Library Size']), bottom_10.head(10)
top_10
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 12           cz         Czechia                7325             5234
# 51           sk        Slovakia                7035             5055
# 24           hu         Hungary                6884             4802
# 6            bg        Bulgaria                6797             4819
# 61           gb  United Kingdom                6643             4551
# 28           ie         Ireland                6486             4515
# 34           lt       Lithuania                6462             4490
# 15           ee         Estonia                6456             4486
# 32           lv          Latvia                6450             4479
# 25           is         Iceland                6387             4426
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 12           2091                        8.83                          11.49
# ...

# %%
bottom_10
# Out:
#    Country_code        Country  Total Library Size  No. of TV Shows  \
# 11           hr        Croatia                2274             1675
# 49           sm     San Marino                2310             1937
# 33           li  Liechtenstein                3048             1712
# 27           id      Indonesia                3887             2449
# 37           md        Moldova                3937             2473
# 16           fi        Finland                4045             2638
# 55           se         Sweden                4361             2973
# 41           no         Norway                4528             2955
# 13           dk        Denmark                4558             2978
# 59           tr         Turkey                4639             2930
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 11            599                        9.03                          11.29
# ...

# %%
random_10
# Out:
#    Country_code        Country  Total Library Size  No. of TV Shows  \
# 36           mx         Mexico                4993             3158
# 54           es          Spain                5229             3536
# 6            bg       Bulgaria                6797             4819
# 62           us  United States                5818             3826
# 53           kr    South Korea                5195             3334
# 39           nl    Netherlands                5376             3779
# 33           li  Liechtenstein                3048             1712
# 40           nz    New Zealand                6084             4003
# 10           cr     Costa Rica                4988             3152
# 18           de        Germany                5668             3814
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 36           1835                        6.62                          10.43
# ...

# %%
# Chart 1 - Histogram -> Distribtion of TV Shows and Movies and Total Library Size
plt.hist(df['No. of TV Shows'], label='Number of TV Shows')
plt.hist(df['No. of Movies'], color='y', label='Number of Movies')
plt.hist(df['Total Library Size'], label='Total Library Size')
plt.legend()
plt.show()

# %%
# Chart 2 - Bar Plot -> Country vs Library Size
bar1 = plt.bar(top_10['Country'], top_10['Total Library Size'], color='magenta', label='Top 10')
bar2 = plt.bar(bottom_10['Country'], bottom_10['Total Library Size'], color='g', label='Bottom 10')
plt.xticks(rotation=90)
plt.ylabel('Total Library Size')
plt.title('Total Library Size by Country')
plt.legend()
plt.show()

# %%
# Chart 3 - Scatter Plot -> Price vs Country
fig = plt.figure(figsize=(9.5, 3))
axs = fig.add_axes([0, 0, 1, 1])
axs.scatter(df.Country, df['Cost Per Month - Basic ($)'], color='r', marker='p', label='Cost Per Month - Basic ($)')
axs.scatter(df.Country, df['Cost Per Month - Standard ($)'], color='cyan', marker='s', label='Cost Per Month - Standard ($)')
axs.scatter(df.Country, df['Cost Per Month - Premium ($)'], color='pink', label='Cost Per Month - Premium ($)')
plt.legend(bbox_to_anchor=(1.3, 1)) # This is only from Python 3.6+ btw
plt.ylabel('Cost in USD')
plt.title('Cost by Country')
plt.xticks(rotation=90)
plt.show()

# %%
# df2 = pd.read_csv('netflix price in different countries.csv')
# df2
